# %%
# DataFrames
import numpy as np
import pandas as pd

# %%
mydata = np.array([[10,20,30],[40,50,60],[70,80,90]])

# %%
myrows = ['row1','row2','row3']

# %%
mycols = ['col1','col2','col3']

# %%
mydata
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
df = pd.DataFrame(mydata, index=myrows, columns=mycols)

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# Selecting Columns
df['col1']
# Out:
# row1    10
# row2    40
# row3    70
# Name: col1, dtype: int32

# %%
df[['col1','col3']]
# Out:
#       col1  col3
# row1    10    30
# row2    40    60
# row3    70    90

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['col2']
# Out:
# row1    20
# row2    50
# row3    80
# Name: col2, dtype: int32

# %%
df['newcol'] = [10,20,30]

# %%
df
# Out:
#       col1  col2  col3  newcol
# row1    10    20    30      10
# row2    40    50    60      20
# row3    70    80    90      30

# %%
df.drop('newcol',axis = 1)
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# axis 
# 0 = rows
# 1 = columns

# %%
df.shape
# Out:
# (3, 4)

# %%
df.shape[0]
# Out:
# 3

# %%
df.shape[1]
# Out:
# 4

# %%
df
# Out:
#       col1  col2  col3  newcol
# row1    10    20    30      10
# row2    40    50    60      20
# row3    70    80    90      30

# %%
df_new = df.drop('newcol', axis = 1)

# %%
df_new
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
df
# Out:
#       col1  col2  col3  newcol
# row1    10    20    30      10
# row2    40    50    60      20
# row3    70    80    90      30

# %%
df.drop('newcol',axis = 1, inplace=True)

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# cre new col - should be sum of col1 & col2 - 30, 90, 150
df['col4'] = df['col1']*10+df['col2']*0.5

# %%
df
# Out:
#       col1  col2  col3   col4
# row1    10    20    30  110.0
# row2    40    50    60  425.0
# row3    70    80    90  740.0

# %%
df.drop('col4', axis = 1, inplace = True)

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# Selecting rows
# 1 by location - loc
# 2 by index - iloc

# %%
df.loc['row2']
# Out:
# col1    40
# col2    50
# col3    60
# Name: row2, dtype: int32

# %%
df.loc[['row1','row3']]
# Out:
#       col1  col2  col3
# row1    10    20    30
# row3    70    80    90

# %%
df.iloc[1]
# Out:
# col1    40
# col2    50
# col3    60
# Name: row2, dtype: int32

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
df.iloc[[0,2]]
# Out:
#       col1  col2  col3
# row1    10    20    30
# row3    70    80    90

# %%
pwd
# Out:
# 'D:\\Users\\nitin'

# %%
cardf = pd.read_csv('D:\\Users\\nitin\\datasets\\cars.csv', index_col = 0)

# %%
cardf
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
cardf.shape
# Out:
# (32, 11)

# %%
cardf.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
cardf.tail()
# Out:
#                  mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# Lotus Europa    30.4    4   95.1  113  3.77  1.513  16.9   1   1     5     2
# Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5     4
# Ferrari Dino    19.7    6  145.0  175  3.62  2.770  15.5   0   1     5     6
# Maserati Bora   15.0    8  301.0  335  3.54  3.570  14.6   0   1     5     8
# Volvo 142E      21.4    4  121.0  109  4.11  2.780  18.6   1   1     4     2

# %%
cardf.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
cardf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
# mpg     32 non-null float64
# cyl     32 non-null int64
# disp    32 non-null float64
# hp      32 non-null int64
# drat    32 non-null float64
# wt      32 non-null float64
# qsec    32 non-null float64
# vs      32 non-null int64
# am      32 non-null int64
# gear    32 non-null int64
# carb    32 non-null int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
cardf.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
cardf
# Select - Datsun 710 & Valiant
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
cardf[cardf.columns[1:5]]
# Out:
#                      cyl   disp   hp  drat
# Mazda RX4              6  160.0  110  3.90
# Mazda RX4 Wag          6  160.0  110  3.90
# Datsun 710             4  108.0   93  3.85
# Hornet 4 Drive         6  258.0  110  3.08
# Hornet Sportabout      8  360.0  175  3.15
# Valiant                6  225.0  105  2.76
# Duster 360             8  360.0  245  3.21
# Merc 240D              4  146.7   62  3.69
# Merc 230               4  140.8   95  3.92
# Merc 280               6  167.6  123  3.92
# Merc 280C              6  167.6  123  3.92
# Merc 450SE             8  275.8  180  3.07
# Merc 450SL             8  275.8  180  3.07
# Merc 450SLC            8  275.8  180  3.07
# Cadillac Fleetwood     8  472.0  205  2.93
# Lincoln Continental    8  460.0  215  3.00
# Chrysler Imperial      8  440.0  230  3.23
# Fiat 128               4   78.7   66  4.08
# Honda Civic            4   75.7   52  4.93
# Toyota Corolla         4   71.1   65  4.22
# Toyota Corona          4  120.1   97  3.70
# ...

# %%
cardf[cardf.columns[[1,3,5,9]]]
# Out:
#                      cyl   hp     wt  gear
# Mazda RX4              6  110  2.620     4
# Mazda RX4 Wag          6  110  2.875     4
# Datsun 710             4   93  2.320     4
# Hornet 4 Drive         6  110  3.215     3
# Hornet Sportabout      8  175  3.440     3
# Valiant                6  105  3.460     3
# Duster 360             8  245  3.570     3
# Merc 240D              4   62  3.190     4
# Merc 230               4   95  3.150     4
# Merc 280               6  123  3.440     4
# Merc 280C              6  123  3.440     4
# Merc 450SE             8  180  4.070     3
# Merc 450SL             8  180  3.730     3
# Merc 450SLC            8  180  3.780     3
# Cadillac Fleetwood     8  205  5.250     3
# Lincoln Continental    8  215  5.424     3
# Chrysler Imperial      8  230  5.345     3
# Fiat 128               4   66  2.200     4
# Honda Civic            4   52  1.615     4
# Toyota Corolla         4   65  1.835     4
# Toyota Corona          4   97  2.465     3
# ...

# %%
mycols = cardf.columns[[1,3,5,9]]

# %%
cardf.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
cardf[mycols]
# Out:
#                      cyl   hp     wt  gear
# Mazda RX4              6  110  2.620     4
# Mazda RX4 Wag          6  110  2.875     4
# Datsun 710             4   93  2.320     4
# Hornet 4 Drive         6  110  3.215     3
# Hornet Sportabout      8  175  3.440     3
# Valiant                6  105  3.460     3
# Duster 360             8  245  3.570     3
# Merc 240D              4   62  3.190     4
# Merc 230               4   95  3.150     4
# Merc 280               6  123  3.440     4
# Merc 280C              6  123  3.440     4
# Merc 450SE             8  180  4.070     3
# Merc 450SL             8  180  3.730     3
# Merc 450SLC            8  180  3.780     3
# Cadillac Fleetwood     8  205  5.250     3
# Lincoln Continental    8  215  5.424     3
# Chrysler Imperial      8  230  5.345     3
# Fiat 128               4   66  2.200     4
# Honda Civic            4   52  1.615     4
# Toyota Corolla         4   65  1.835     4
# Toyota Corona          4   97  2.465     3
# ...

# %%
cardf
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
cardf>0
# Out:
#                       mpg   cyl  disp    hp  drat    wt  qsec     vs     am  \
# Mazda RX4            True  True  True  True  True  True  True  False   True
# Mazda RX4 Wag        True  True  True  True  True  True  True  False   True
# Datsun 710           True  True  True  True  True  True  True   True   True
# Hornet 4 Drive       True  True  True  True  True  True  True   True  False
# Hornet Sportabout    True  True  True  True  True  True  True  False  False
# Valiant              True  True  True  True  True  True  True   True  False
# Duster 360           True  True  True  True  True  True  True  False  False
# Merc 240D            True  True  True  True  True  True  True   True  False
# Merc 230             True  True  True  True  True  True  True   True  False
# Merc 280             True  True  True  True  True  True  True   True  False
# Merc 280C            True  True  True  True  True  True  True   True  False
# ...

# %%
cardf[cardf>0]
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec   vs   am  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46  NaN  1.0
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02  NaN  1.0
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61  1.0  1.0
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44  1.0  NaN
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02  NaN  NaN
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22  1.0  NaN
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84  NaN  NaN
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00  1.0  NaN
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90  1.0  NaN
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30  1.0  NaN
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90  1.0  NaN
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40  NaN  NaN
# ...

# %%
# Find out all the cars that has mpg 20
cardf[cardf['mpg']>20]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4       21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710      22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# Fiat 128        32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# Honda Civic     30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# Toyota Corona   21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# Fiat X1-9       27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# ...

# %%
# Select cars that has am = 0 & mpg is greater than 20
cardf[(cardf['mpg']>20) & (cardf['am']==0)]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# Toyota Corona   21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1

# %%
# Select cars that has am = 0 & mpg is greater than 20
newcardf = cardf[(cardf['mpg']>20) | (cardf['am']==0)]

# %%
newcardf
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
cardf
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
mynewcar = cardf.reset_index()

# %%
mynewcar.columns
# Out:
# Index(['index', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
mynewcar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# index    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# disp     32 non-null float64
# hp       32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
mynewcar.shape
# Out:
# (32, 12)

# %%
mynewcar_h = mynewcar.head()

# %%
mynewcar_h['mynewcolindex']=['a','b','c','d','e']
# Out:
# D:\Users\nitin\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mynewcar_h
# Out:
#                index   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb mynewcolindex
# 0     4             a
# 1     4             b
# 2     1             c
# 3     1             d
# 4     2             e

# %%
mynewcar_h.set_index('mynewcolindex')
# Out:
#                            index   mpg  cyl   disp   hp  drat     wt   qsec  \
# mynewcolindex
# a                      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46
# b                  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02
# c                     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61
# d                 Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44
# e              Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02
#
#                vs  am  gear  carb
# mynewcolindex
# a               0   1     4     4
# b               0   1     4     4
# c               1   1     4     1
# d               1   0     3     1
# e               0   0     3     2

# %% [markdown]
# # Group By
# GroupBy - Function is used to split the data into groups based on some criteria & apply some aggregate function on them. Pandas objects can be split on any of their axes.

# %%
data = {
    'company':['Samphone','Samphone','MIPhone','MIPhone','iPhone','iPhone'],
    'person':['Jack','Tim','Jenifer','Amy','Sarah','Bob'],
    'sales':[2000,3000,2500,1004,9000,2500],
    'qty':[10,16,12,30,10,12]
}

# %%
data
# Out:
# {'company': ['Samphone', 'Samphone', 'MIPhone', 'MIPhone', 'iPhone', 'iPhone'],
#  'person': ['Jack', 'Tim', 'Jenifer', 'Amy', 'Sarah', 'Bob'],
#  'sales': [2000, 3000, 2500, 1004, 9000, 2500],
#  'qty': [10, 16, 12, 30, 10, 12]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     company   person  sales  qty
# 0  Samphone     Jack   2000   10
# 1  Samphone      Tim   3000   16
# 2   MIPhone  Jenifer   2500   12
# 3   MIPhone      Amy   1004   30
# 4    iPhone    Sarah   9000   10
# 5    iPhone      Bob   2500   12

# %%
df.groupby('company')

# %%
df.groupby('company').mean()
# Out:
#           sales  qty
# company
# MIPhone    1752   21
# Samphone   2500   13
# iPhone     5750   11

# %%
df.groupby('company').sum()
# Out:
#           sales  qty
# company
# MIPhone    3504   42
# Samphone   5000   26
# iPhone    11500   22

# %%
df
# Out:
#     company   person  sales  qty
# 0  Samphone     Jack   2000   10
# 1  Samphone      Tim   3000   16
# 2   MIPhone  Jenifer   2500   12
# 3   MIPhone      Amy   1004   30
# 4    iPhone    Sarah   9000   10
# 5    iPhone      Bob   2500   12
