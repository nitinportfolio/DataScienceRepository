# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import spacy

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC, LinearSVC

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import Pipeline

# %%
data = pd.read_csv('.\data\\twitter_data30k.csv')

# %%
data.head()
# Out:
#                                               twitts  sentiment
# 0       @robbiebronniman Sounds like a great night.           1
# 1  Damn the person who stolde my wallet !!!!!  Ma...          1
# 2  Greetings from the piano bench  (photo) http:/...          1
# 3  @drewryanscott i love it!! i love you!! haha f...          1
# 4  @kissthestars Pretty pretty pretty please, pak...          0

# %%
data['sentiment'].value_counts()
# Out:
# 1    15000
# 0    15000
# Name: sentiment, dtype: int64

# %%
def svm_pred(data):
    X = data['twitts']
    y = data['sentiment']

    tfidf = TfidfVectorizer(norm='l1')
    X=tfidf.fit_transform(X)

    X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0, stratify=y)

    print('Shape of X: ',X.shape )

    clf = LinearSVC()
    clf.fit(X_train,y_train)

    y_pred = clf.predict(X_test)

    print()
    print('Printing Report')
    print(classification_report(y_test, y_pred))
    
    return tfidf, clf

# %%
# %%time
tfidf,clf = svm_pred(data)
# Out:
# Shape of X:  (30000, 43007)
#
# Printing Report
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      3000
#            1       0.76      0.76      0.76      3000
#
#     accuracy                           0.76      6000
#    macro avg       0.76      0.76      0.76      6000
# weighted avg       0.76      0.76      0.76      6000
#
# Wall time: 1.03 s

# %%
mysent = ['Eating fats is bad']

mypred = clf.predict(tfidf.transform(mysent))
mypred
# 1 means positive sentiment
# Out:
# array([0], dtype=int64)

# %%
print(np.where(mypred==1,'Its a positive sentiment','Its a negative sentiment'))
# Out:
# ['Its a negative sentiment']

# %%
import textpreprocess_2022 as pp

# %%
pp.__version__
# Out:
# '0.0.1'

# %%
data['twitts'] =data['twitts'].apply(lambda x: x.lower())

# %%
data['twitts']
# Out:
# 0                robbiebronniman sounds like a great night
# 1        damn the person who stolde my wallet may karma...
# 2                     greetings from the piano bench photo
# 3        drewryanscott i love it i love you haha forget...
# 4        kissthestars pretty pretty pretty please pakid...
#                                ...
# 29995      calumfan1 is it in any way related to photoshop
# 29996                        swiz_nz really wow thats crap
# 29997    at the 2010 lexus hs250h press event again can...
# 29998    karmicunderpath ooooh now there is a nice thought
# 29999    mariap91 id usually ask you about the sun and ...
# Name: twitts, Length: 30000, dtype: object

# %%
data['twitts']=data['twitts'].apply(lambda x: pp.cont_ext(x))

# %%
svm_pred(data)
# Out:
# Shape of X:  (30000, 43007)
#
# Printing Report
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      3000
#            1       0.76      0.76      0.76      3000
#
#     accuracy                           0.76      6000
#    macro avg       0.76      0.76      0.76      6000
# weighted avg       0.76      0.76      0.76      6000
# (TfidfVectorizer(norm='l1'), LinearSVC())

# %%
data['twitts']=data['twitts'].apply(lambda x: pp.remove_emails(x))
data['twitts']=data['twitts'].apply(lambda x: pp.remove_urls(x))
data['twitts']=data['twitts'].apply(lambda x: pp.remove_rt(x))
data['twitts']=data['twitts'].apply(lambda x: pp.remove_html_tags(x))
data['twitts']=data['twitts'].apply(lambda x: pp.remove_special_chars(x))

# %%
#pp.remove_emails('Hello nitin contact@gmail.com, is my mail id. New mail id is contactme@acb.com')

# %%
tfidf, clf = svm_pred(data)
# Out:
# Shape of X:  (30000, 43007)
#
# Printing Report
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      3000
#            1       0.76      0.76      0.76      3000
#
#     accuracy                           0.76      6000
#    macro avg       0.76      0.76      0.76      6000
# weighted avg       0.76      0.76      0.76      6000

# %% [markdown]
# ## Saving & Loading the Model

# %%
import pickle

# %%
# wb - write binary mode
pickle.dump(clf, open('clf.pkl','wb'))
pickle.dump(tfidf,open('tfidf.pkl','wb'))

# %%
tfidf
# Out:
# TfidfVectorizer(norm='l1')

# %%
clf
# Out:
# LinearSVC()

# %%
del tfidf

# %%
del clf

# %%
# rb - read binary mode
clf = pickle.load(open('clf.pkl','rb'))
tfidf = pickle.load(open('tfidf.pkl','rb'))

# %%
clf
# Out:
# LinearSVC()

# %%
tfidf
# Out:
# TfidfVectorizer(norm='l1')

# %%
# How many times below words are occcured in our dataframe or data
tfidf.vocabulary_
# Out:
# {'robbiebronniman': 31627,
#  'sounds': 34837,
#  'like': 21885,
#  'great': 15496,
#  'night': 26468,
#  'damn': 9485,
#  'the': 37224,
#  'person': 28602,
#  'who': 41168,
#  'stolde': 35583,
#  'my': 25714,
#  'wallet': 40502,
#  'may': 23738,
#  'karma': 20160,
#  'come': 8217,
#  'back': 3763,
#  'and': 2511,
#  'bite': 4889,
#  'you': 42492,
#  'in': 17928,
#  'ass': 3274,
#  'greetings': 15547,
#  'from': 14248,
#  'piano': 28818,
#  'bench': 4526,
#  'photo': 28775,
#  'drewryanscott': 11310,
#  'love': 22562,
#  'it': 18503,
#  'haha': 15891,
#  'forget': 13921,
#  'hugyou': 17339,
#  'should': 33661,
#  'give': 14998,
#  'me': 23859,
#  'kissno': 20736,
#  'lie': 21817,
#  'please': 29115,
#  'would': 41743,
#  'be': 4210,
#  'awesome': 3577,
#  'if': 17691,
#  'did': 10484,
#  'kissthestars': 20737,
#  'pretty': 29651,
#  'pakidownload': 28017,
#  'ito': 18553,
#  'then': 37396,
#  'reupload': 31335,
#  'someother': 34649,
#  'site': 34005,
#  'mediafire': 23903,
#  'hindi': 16816,
#  'mgwork': 24249,
#  'ang': 2585,
#  'mu': 25526,
#  'skin': 34067,
#  'really': 30702,
#  'upset': 39718,
#  'lilyroseallen': 21946,
#  'big': 4744,
#  'pool': 29321,
#  'or': 27599,
#  'paddling': 27966,
#  'might': 24392,
#  'able': 1256,
#  'to': 38083,
#  'manage': 23212,
#  'paddle': 27965,
#  'surroundings': 36238,
#  'but': 6246,
#  'that': 37186,
#  'is': 18431,
#  'as': 3154,
#  'luxury': 22826,
#  'will': 41304,
#  'get': 14810,
#  'arianna_skye': 3035,
#  'hee': 16455,
#  'tweet': 39025,
#  'are': 3007,
#  '10001': 37,
#  'lol': 22337,
#  'happy': 16117,
#  'have': 16249,
#  'tickets': 37804,
#  'for': 13892,
#  'concerts': 8382,
#  'mileycyrus': 24481,
#  'miley': 24477,
#  'look': 22425,
#  'soooo': 34736,
#  'much': 25532,
#  'better': 4654,
#  'this': 37601,
#  'its': 18559,
#  'laid': 21193,
#  'mustgotobedearly': 25678,
#  'shhhhquitely': 33483,
#  'nowcome': 26892,
#  'see': 32940,
#  'found': 13996,
#  'hole': 16943,
#  'fence': 13298,
#  'uh': 39378,
#  'oh': 27244,
#  'sound': 34830,
#  'messed': 24184,
#  'up': 39678,
#  'on': 27436,
#  'cable': 6371,
#  'festï½s': 13334,
#  'what': 41048,
#  'im': 17815,
#  'not': 26817,
#  'best': 4606,
#  'finally': 13460,
#  'made': 22986,
#  'hammock': 16031,
#  'innagual': 18139,
#  'yahooooooooo': 42199,
#  'peace': 28433,
#  'harmony': 16171,
#  'mitchelmusso': 24778,
#  'allowed': 2156,
#  'call': 6461,
#  'live': 22140,
#  'uk': 39401,
#  'parents': 28169,
#  'say': 32573,
#  'cost': 8731,
#  'sucks': 35923,
#  'sandysaikman': 32391,
#  'do': 10907,
#  'makes': 23129,
#  'sad': 32183,
#  'know': 20843,
#  'how': 17248,
#  'talk': 36593,
#  'so': 34498,
#  'favourite': 13194,
#  'silver': 33873,
#  'hook': 17078,
#  'which': 41118,
#  'very': 40045,
#  'nutty': 27018,
#  'out': 27738,
#  'of': 27161,
#  'stock': 35570,
#  'right': 31502,
#  'now': 26884,
#  'leaving': 21549,
#  'hell': 16515,
#  'car': 6631,
#  'awfulugh': 3596,
#  'just': 19941,
#  'realised': 30679,
#  'ive': 18636,
#  'spent': 34984,
#  'â475': 42819,
#  'clothes': 7948,
#  'today': 38111,
#  'singing': 33941,
#  'duo': 11530,
#  'with': 41451,
#  'an': 2476,
#  'aussie': 3464,
#  'koala': 20867,
#  'wwwmarcopallicom': 41919,
#  'mahafreed': 23068,
#  'running': 32044,
#  'battery': 4119,
#  '20': 296,
#  'wont': 41566,
#  'last': 21324,
#  'long': 22405,
#  'anyway': 2834,
#  'planning': 29051,
#  'soon': 34717,
#  'more': 25171,
#  'daru': 9687,
#  'zidman8': 42733,
#  'was': 40601,
#  'nice': 26370,
#  'meeting': 23950,
#  'too': 38336,
#  'work': 41637,
#  'minute': 24595,
#  'truejerseygirl': 38812,
#  'went': 40969,
#  'kid': 20574,
#  'scotland': 32751,
#  'north': 26794,
#  'sea': 32850,
#  'they': 37531,
#  'were': 40976,
#  'catching': 6856,
#  'cod': 8052,
#  'whacking': 41041,
#  'them': 37377,
#  'head': 16323,
#  'cried': 9031,
#  'whole': 41182,
#  'time': 37878,
#  'at': 3332,
#  'must': 25673,
#  'eat': 11691,
#  'first': 13540,
#  'leftover': 21595,
#  'chinese': 7430,
#  'calling': 6468,
#  'ri_guy': 31418,
#  'bad': 3813,
#  'thats': 37211,
#  'happend': 16101,
#  'tara': 36682,
#  'excited': 12744,
#  'no': 26638,
#  'go': 15120,
#  'sorry': 34798,
#  'getting': 14827,
#  'ready': 30659,
#  'fun': 14351,
#  'day': 9803,
#  'laying': 21467,
#  'sun': 36040,
#  'before': 4412,
#  'new': 26263,
#  'schedule': 32674,
#  'kicks': 20572,
#  'sunday': 36060,
#  'edmercer': 11803,
#  'well': 40919,
#  'said': 32234,
#  'by': 6330,
#  'piaget': 28816,
#  'packing': 27951,
#  'home': 16990,
#  'bostonyay': 5476,
#  'james__buckley': 18803,
#  'hope': 17104,
#  'ouve': 27798,
#  'got': 15344,
#  'your': 42517,
#  'suncream': 36055,
#  'coz': 8853,
#  'amanda21crook': 2284,
#  'burnt': 6194,
#  'beach': 4214,
#  'yesterday': 42394,
#  'alroker': 2228,
#  'hi': 16712,
#  'al': 1922,
#  'near': 26073,
#  'lake': 21202,
#  'george': 14771,
#  'ny': 27037,
#  'frost': 14259,
#  'covered': 8829,
#  'flowers': 13725,
#  'veggie': 39976,
#  'plants': 29061,
#  'june': 19914,
#  '1st': 283,
#  'happens': 16108,
#  'we': 40732,
#  'moving': 25337,
#  'summer': 36009,
#  'ball': 3899,
#  'amazing': 2321,
#  'however': 17253,
#  'feeling': 13258,
#  'death': 9962,
#  'sitting': 34012,
#  'bed': 4343,
#  'cuppa': 9245,
#  'watching': 40636,
#  'office': 27191,
#  'thehurricaneee': 37348,
#  'hot': 17173,
#  'tamale': 36621,
#  'wayknee': 40692,
#  'ahhh': 1765,
#  'same': 32311,
#  'vicentemendoza': 40094,
#  'agree': 1728,
#  'am': 2271,
#  'still': 35523,
#  'ep10': 12344,
#  'heard': 16366,
#  'about': 1263,
#  'suicide': 35977,
#  'thingy': 37572,
#  'yi': 42428,
#  'jungga': 19919,
#  'eul': 12553,
#  'tandem': 36642,
#  'soo': 34713,
#  'exhausted': 12772,
#  'feel': 13254,
#  'sick': 33770,
#  'cant': 6583,
#  'anymore': 2819,
#  'princesita015': 29701,
#  'london': 22391,
#  'one': 27444,
#  'most': 25246,
#  'cities': 7732,
#  'ever': 12616,
#  'been': 4395,
#  'anonyw': 2742,
#  'yea': 42282,
#  'sha': 33210,
#  'nggak': 26332,
#  'di': 10440,
#  'officialin': 27208,
#  'kesel': 20478,
#  'abis': 1249,
#  'left': 21590,
#  'brooklyn': 5903,
#  'bumping': 6141,
#  'sarah': 32424,
#  'white': 41156,
#  'soundz': 34840,
#  'fly': 13754,
#  'don': 11015,
#  'cuco': 9195,
#  'ms': 25444,
#  'blanca': 4986,
#  'goodluck': 15246,
#  'en': 12198,
#  'espana': 12486,
#  'balmainbazaar': 3911,
#  'facehunter': 12943,
#  'embarrassing': 12087,
#  'representation': 31175,
#  'compare': 8301,
#  'swedes': 36352,
#  'all': 2093,
#  'born': 5456,
#  'stylish': 35850,
#  'watch': 40628,
#  'saw': 32566,
#  'iv': 18631,
#  'drink': 11328,
#  'lil': 21913,
#  'wine': 41374,
#  'stoshad': 35643,
#  'almost': 2180,
#  'bought': 5496,
#  'bullpen': 6115,
#  'hat': 16215,
#  'thought': 37680,
#  'douchey': 11146,
#  'possibilities': 29421,
#  'somehow': 34640,
#  'urgh': 39753,
#  'playing': 29094,
#  'game': 14550,
#  'hour': 17206,
#  'computer': 8354,
#  'decided': 10009,
#  'needs': 26107,
#  'restartbefore': 31259,
#  'could': 8762,
#  'chance': 7105,
#  'save': 32553,
#  'pdfloral': 28423,
#  'miss': 24648,
#  'having': 16263,
#  'retail': 31293,
#  'store': 35619,
#  'lot': 22518,
#  'another': 2745,
#  'loved': 22572,
#  'being': 4445,
#  'own': 27881,
#  'shop': 33620,
#  'girl': 14958,
#  'stevenleedawson': 35483,
#  'missed': 24678,
#  'vodka': 40284,
#  'food': 13856,
#  'chips': 7455,
#  'milk': 24494,
#  'together': 38176,
#  'already': 2214,
#  'reading': 30652,
#  'days': 9834,
#  'jackyan': 18737,
#  'good': 15225,
#  'solutions': 34626,
#  'heh': 16471,
#  'hey': 16668,
#  'fam': 13031,
#  'teemwilliams': 36907,
#  'show': 33678,
#  'tonight': 38296,
#  'sure': 36204,
#  'though': 37673,
#  'feels': 13265,
#  'havent': 16256,
#  'seen': 32964,
#  'perform': 28569,
#  'aggess': 1700,
#  'uploading': 39710,
#  'photos': 28793,
#  'facebook': 12939,
#  'friendster': 14208,
#  'myspace': 25762,
#  'later': 21351,
#  'poor': 29334,
#  'little': 22115,
#  'has': 16197,
#  'cold': 8111,
#  'need': 26100,
#  'sleep': 34180,
#  'meet': 23948,
#  'friend': 14186,
#  'hotjane': 17183,
#  'yeah': 42294,
#  'um': 39435,
#  'jane': 18856,
#  'only': 27475,
#  'unboring': 39471,
#  'eye': 12887,
#  'candy': 6559,
#  'around': 3087,
#  'there': 37445,
#  'hon': 17044,
#  'canberra': 6542,
#  'think': 37574,
#  'can': 6531,
#  'dance': 9516,
#  'goin': 15175,
#  'sleeping': 34193,
#  'beacose': 4232,
#  'tomorrow': 38252,
#  'sports': 35090,
#  'bngr': 5210,
#  'chesterfield': 7340,
#  'ave': 3522,
#  'main': 23086,
#  'road': 31601,
#  'way': 40688,
#  'through': 37726,
#  'heuston': 16663,
#  'gates': 14627,
#  'used': 39779,
#  'chilfreebies': 7406,
#  'franchise': 14050,
#  'type': 39289,
#  'business': 6224,
#  'princesammie': 29700,
#  'joined': 19580,
#  'honeymagazine': 17054,
#  'website': 40788,
#  'couldnt': 8765,
#  'find': 13475,
#  'add': 1473,
#  'icaruswingz': 17614,
#  'cunt': 9233,
#  'weeks': 40861,
#  'copy': 8656,
#  'rr': 31955,
#  'wait': 40446,
#  'oops': 27547,
#  'nevermind': 26255,
#  'billboard': 4791,
#  'ericakelly01': 12401,
#  'goodnight': 15255,
#  'dodger': 10930,
#  'burned': 6187,
#  'vanunu': 39930,
#  'yes': 42375,
#  'happened': 16102,
#  'baby': 3733,
#  'howie_d': 17255,
#  'gonna': 15217,
#  'take': 36567,
#  'care': 6654,
#  'he': 16321,
#  'strong': 35747,
#  'boy': 5536,
#  'attempting': 3385,
#  'hopefully': 17109,
#  'renblink182': 31107,
#  'ok': 27302,
#  'ill': 17766,
#  'msn': 25489,
#  'bit': 4877,
#  'off': 27166,
#  'chippy': 7454,
#  'mo': 24890,
#  'dinner': 10577,
#  'speak': 34936,
#  'laters': 21358,
#  'mishmash878': 24636,
#  'week': 40831,
#  'hand': 16043,
#  'starting': 35331,
#  'yal': 42208,
#  'sophomre': 34777,
#  'kim': 20635,
#  'sang': 32394,
#  'bum': 6123,
#  'tvhaha': 38986,
#  'tynzboompow': 39288,
#  'crazy': 8966,
#  'her': 16592,
#  'songs': 34686,
#  'rid': 31482,
#  'recently': 30761,
#  'regret': 30955,
#  'alot': 2199,
#  'davidarchie': 9755,
#  'concert': 8380,
#  'david': 9746,
#  'cook': 8577,
#  'both': 5479,
#  'singers': 33938,
#  'physics': 28809,
#  'actually': 1437,
#  'sayin': 32580,
#  'tonyprice': 38333,
#  'job': 19462,
#  'again': 1665,
#  '2nyt': 465,
#  'friends': 14197,
#  'luvd': 22812,
#  'ur': 39734,
#  'pimp': 28900,
#  'dtphulp': 11438,
#  'voice': 40290,
#  'some': 34634,
#  'euh': 12552,
#  'finetuning': 13486,
#  'omjitssarax3': 27426,
#  'make': 23119,
#  'things': 37565,
#  'ed': 11755,
#  'mcmahon': 23829,
#  'nooo': 26745,
#  'also': 2230,
#  'accident': 1333,
#  'airport': 1851,
#  'structural': 35756,
#  'failure': 12982,
#  'called': 6463,
#  'tired': 37978,
#  'fvck': 14438,
#  'didnt': 10493,
#  'slp': 34271,
#  'darthslr': 9686,
#  'gmail': 15094,
#  'working': 41662,
#  'either': 11909,
#  'sort': 34802,
#  'broken': 5884,
#  'hp': 17269,
#  'printer': 29719,
#  'had': 15877,
#  'couple': 8792,
#  'months': 25106,
#  'currys': 9273,
#  'hmm': 16879,
#  'until': 39658,
#  'answer': 2751,
#  'fsdt': 14291,
#  'annouced': 2718,
#  'when': 41098,
#  'shit': 33544,
#  'college': 8162,
#  'life': 21829,
#  'laugh': 21374,
#  'mtv': 25522,
#  'hate': 16217,
#  'sleepovers': 34204,
#  'shannon': 33300,
#  'mount': 25285,
#  'zoomer': 42782,
#  'into': 18294,
#  'comic': 8239,
#  'tear': 36850,
#  'friendley': 14191,
#  'trying': 38840,
#  'many': 23312,
#  'people': 28536,
#  'follow': 13811,
#  'check': 7240,
#  'acemansworldcom': 1369,
#  'cool': 8598,
#  'heading': 16340,
#  'internet': 18259,
#  'next': 26309,
#  'jonas_dreamgirl': 19624,
#  'waiting': 40452,
#  'nail': 25867,
#  'polish': 29275,
#  'dry': 11414,
#  'gotta': 15359,
#  'hair': 15955,
#  'makeup': 23131,
#  'xoxo': 42090,
#  'hates': 16229,
#  'babysit': 3748,
#  'while': 41124,
#  'bus': 6213,
#  'carlisle': 6693,
#  '11ish': 121,
#  'likely': 21895,
#  'smiths': 34353,
#  'fest': 13330,
#  'sims': 33915,
#  'perhaps': 28577,
#  'monday': 25032,
#  'going': 15177,
#  'ground': 15624,
#  'zero': 42721,
#  'dont': 11068,
#  'wanna': 40536,
#  'reasons': 30726,
#  'mmmicaela': 24858,
#  'ha': 15839,
#  'jamescantbeseen': 18807,
#  'imy2': 17927,
#  'sicker': 33772,
#  'than': 37145,
#  'thank': 37151,
#  'god': 15139,
#  'nyais': 27040,
#  'operation': 27567,
#  'successful': 35903,
#  'here': 16601,
#  'lying': 22848,
#  'sleepy': 34211,
#  'datarock': 9705,
#  'rock': 31693,
#  'painting': 28006,
#  'sexycitymag': 33179,
#  'want': 40543,
#  'anc153': 2505,
#  'luckyyy': 22722,
#  'apparently': 2894,
#  'robeks': 31637,
#  'entire': 12315,
#  'state': 35350,
#  'pa': 27925,
#  'renato71': 31106,
#  'morning': 25194,
#  'nisher': 26581,
#  'heck': 16446,
#  'sastch': 32504,
#  'year': 42317,
#  'bail': 3866,
#  'lack': 21138,
#  'expenses': 12812,
#  'yelyahwilliams': 42361,
#  'hayley': 16284,
#  'yer': 42370,
#  'biggest': 4759,
#  'fan': 13057,
#  'philippines': 28727,
#  'tim339': 37873,
#  'suppose': 36188,
#  'interview': 18281,
#  'true': 38799,
#  'icon': 17645,
#  'karl': 20148,
#  'lagerfeld': 21183,
#  'amazes': 2318,
#  'him': 16807,
#  'his': 16837,
#  'after': 1644,
#  'dancing': 9529,
#  'shoes': 33589,
#  'blistered': 5071,
#  'feet': 13269,
#  'question': 30206,
#  'ut': 39804,
#  'worth': 41730,
#  'hoping': 17119,
#  'old': 27345,
#  'pulls': 29994,
#  'trumps': 38824,
#  'tip': 37967,
#  'top': 38380,
#  'capeside': 6608,
#  'inexplicably': 18055,
#  'creeped': 9006,
#  'something': 34656,
#  'house': 17216,
#  'scary': 32651,
#  'alone': 2190,
#  'beautiful': 4285,
#  'oo': 27501,
#  'amused': 2446,
#  'xx': 42129,
#  'ugh': 39362,
#  'ate': 3340,
#  'tummy': 38923,
#  'ache': 1375,
#  'ciaobella6': 7667,
#  'yay': 42254,
#  'loving': 22619,
#  'chicken': 7380,
#  'wings': 41385,
#  'kfc': 20522,
#  'finger': 13489,
#  'lickin': 21808,
#  'asfuwegharegu': 3164,
#  'hangovers': 16073,
#  'algebra': 2040,
#  'final': 13452,
#  'midnight': 24367,
#  'loooooong': 22446,
#  'mention': 24125,
#  'kids': 20592,
#  'school': 32689,
#  'whewwhy': 41113,
#  'cannot': 6574,
#  'kind': 20674,
#  'energy': 12252,
#  'kathryn17': 20215,
#  'yet': 42406,
#  'ryanj81': 32113,
#  'single': 33942,
#  '3hours': 574,
#  'birds': 4847,
#  'shot': 33653,
#  'officially': 27216,
#  'middle': 24355,
#  'welshdragon72': 40950,
#  'tell': 36949,
#  'jordi': 19701,
#  'chandler': 7108,
#  'described': 10280,
#  'cock': 8034,
#  'warts': 40599,
#  'losing': 22505,
#  'fast': 13141,
#  'justbreathex': 19956,
#  'lian': 21779,
#  'robmader': 31661,
#  'finish': 13497,
#  'bahama': 3861,
#  'breeze': 5703,
#  'keep': 20353,
#  'perezwill': 28559,
#  'fued': 14325,
#  'xxxx': 42158,
#  'song': 34680,
#  'heart': 16373,
#  'phil': 28714,
#  'collins': 8176,
#  'ipod': 18363,
#  'tarzan': 36710,
#  'soundtrack': 34839,
#  'rules': 32024,
#  'xd': 42013,
#  'wondering': 41553,
#  'anybody': 2810,
#  'reads': 30657,
#  'opportunities': 27577,
#  'walk': 40480,
#  'llama': 22221,
#  'calmer': 6477,
#  'uhoh': 39393,
#  'hear': 16365,
#  'oven': 27804,
#  'bell': 4480,
#  'shortcrust': 33642,
#  'pastry': 28265,
#  'dead': 9924,
#  'start': 35325,
#  'vallovetwilight': 39890,
#  'kudos': 21033,
#  'doll': 10983,
#  'miami': 24271,
#  'laughing': 21378,
#  'buddah': 6045,
#  'hanging': 16067,
#  'topher': 38387,
#  'tsk': 38859,
#  'daddy': 9408,
#  'emo': 12159,
#  'hahaha': 15901,
#  'thingsmomslike': 37569,
#  'wow': 41758,
#  'huge': 17320,
#  'prize': 29742,
#  'congrats': 8442,
#  'camp': 6515,
#  'full': 14339,
#  'religious': 31037,
#  'nuts': 27012,
#  'wide_receiver': 41240,
#  'rubbish': 31979,
#  'weekend': 40839,
#  'suffering': 35952,
#  'eddiekemp': 11766,
#  'does': 10938,
#  'suck': 35910,
#  'following': 13832,
#  'ily': 17808,
#  'sputuk': 35145,
#  'surely': 36207,
#  'audi': 3423,
#  'teehee': 36901,
#  'failedcarmodels': 12975,
#  'via': 40078,
#  'chapla1n': 7138,
#  'yugo': 42591,
#  'angiggle': 2627,
#  'early': 11654,
#  'backstreetboys': 3805,
#  'brian': 5744,
#  'youare': 42495,
#  'adorable': 1544,
#  'funny': 14394,
#  'groundctrl': 15626,
#  'jessako': 19250,
#  'finished': 13499,
#  'product': 29777,
#  'missin': 24684,
#  'lauradman': 21400,
#  'laura': 21394,
#  'maybe': 23744,
#  'catch': 6853,
#  'nap': 25935,
#  'ddlovato': 9907,
#  'uklondon': 39408,
#  'fansite': 13080,
#  'knw': 20865,
#  'gna': 15106,
#  'shw': 33741,
#  'therealrouga': 37458,
#  'sooooo': 34738,
#  'rouga': 31896,
#  'chillin': 7415,
#  'piece': 28859,
#  'plastic': 29064,
#  'fell': 13284,
#  'iphone': 18352,
#  '3g': 570,
#  'tiny': 37960,
#  'between': 4669,
#  'silent': 33854,
#  'button': 6290,
#  'volume': 40305,
#  'buttons': 6291,
#  'lost': 22509,
#  'wanting': 40549,
#  'rollingcherry': 31779,
#  'why': 41219,
#  'zugabe': 42790,
#  'gal': 14525,
#  'dat': 9700,
#  'scholarette': 32686,
#  'onthelow': 27493,
#  'hide': 16730,
#  'keys': 20517,
#  'cell': 7000,
#  'phone': 28759,
#  'stay': 35374,
#  'longer': 22409,
#  'princess_han': 29703,
#  'told': 38198,
#  'happening': 16106,
#  'wish': 41429,
#  'thouht': 37690,
#  'sung': 36075,
#  'disapointed': 10635,
#  'myself': 25753,
#  'nothing': 26836,
#  'accomplished': 1348,
#  'besides': 4599,
#  'looking': 22429,
#  'forward': 13980,
#  'flat': 13630,
#  'soulmate': 34824,
#  'vidal': 40120,
#  'sassoon': 32496,
#  'selfish': 33010,
#  'mean': 23868,
#  'daughteri': 9719,
#  'guess': 15710,
#  'never': 26253,
#  'grow': 15641,
#  'lisjustice': 22076,
#  'davethinkslisgaynohomo': 9744,
#  'rotflmao': 31889,
#  'these': 37502,
#  'bones': 5311,
#  'matthewadamdiaz': 23677,
#  'learn': 21529,
#  'paolakoala': 28107,
#  'miles': 24474,
#  'surrounded': 36236,
#  'steep': 35399,
#  'hills': 16793,
#  'carriemrobison': 6771,
#  'any': 2804,
#  'rocks': 31716,
#  'picnic': 28844,
#  'jazz': 19013,
#  'our': 27731,
#  'area': 3008,
#  'andysalmon': 2573,
#  'coffee': 8077,
#  'workout': 41681,
#  'inbst': 17954,
#  'mall': 23169,
#  'took': 38345,
#  '45': 637,
#  'mins': 24587,
#  'woke': 41521,
#  'kinda': 20675,
#  'warm': 40574,
#  'sore': 34784,
#  'throat': 37721,
#  'allergies': 2113,
#  'gasp': 14619,
#  'swine': 36412,
#  'maker': 23126,
#  'whenever': 41100,
#  'possible': 29424,
#  'adhd': 1501,
#  'clean': 7847,
#  'fizzyduck': 13589,
#  'suggest': 35970,
#  'music': 25644,
#  'electro': 11958,
#  'project': 29811,
#  'fresh': 14153,
#  'kickin': 20569,
#  'different': 10518,
#  'free': 14109,
#  'dl': 10864,
#  'somethings': 34659,
#  'down': 11166,
#  'temporary': 36979,
#  'spaces': 34890,
#  'ebassman': 11710,
#  'yo': 42450,
#  'ya': 42177,
#  'feverishpoptart': 13343,
#  'costing': 8735,
#  '1000': 32,
#  'instead': 18208,
#  '300': 488,
#  'anticipated': 2775,
#  'plane': 29038,
#  'buenos': 6064,
#  'aires': 1844,
#  'apple': 2910,
#  'bobbibillard': 5229,
#  'large': 21303,
#  'number': 26976,
#  '14': 180,
#  'aneshaisaplus': 2581,
#  'creative': 8987,
#  'wut': 41873,
#  'uuuuuu': 39833,
#  'doing': 10967,
#  'thang': 37147,
#  'helbro': 16498,
#  'hicke': 16722,
#  'os': 27681,
#  '30': 487,
#  'available': 3511,
#  '18th': 234,
#  '0100': 3,
#  'local': 22283,
#  '1pm': 281,
#  '17th': 226,
#  'york': 42482,
#  '1900': 236,
#  'central': 7024,
#  'europe': 12563,
#  'techcommdood': 36868,
#  'er': 12379,
#  'cup': 9236,
#  'amandacool': 2289,
#  'beans': 4254,
#  'cacheshantel': 6379,
#  'everyone': 12647,
#  'exams': 12718,
#  'gaaaah': 14472,
#  'fair': 12988,
#  'surprisingly': 36230,
#  'ashleytisdale': 3208,
#  'album': 1958,
#  'listened': 22084,
#  'preview': 29663,
#  'fact': 12952,
#  'spell': 34970,
#  'ridiculous': 31492,
#  'further': 14415,
#  'prove': 29891,
#  ...}

# %%
mysent = ['Eating fats is good']

mypred = clf.predict(tfidf.transform(mysent))
mypred
# Out:
# array([1], dtype=int64)

# %%
import re

# %%
text = 'II llooooveeee WWWWWaaaaaaatching TV'

# %%
x = re.sub("(.)\\1{2,}","\\1",text)
x
# Out:
# 'II llove Watching TV'
