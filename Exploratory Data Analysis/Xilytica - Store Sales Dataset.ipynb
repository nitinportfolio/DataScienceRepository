# %%
import datetime

# %%
# 1st I will quickly go through all 3 datasets to understand them from 30000 feets & also to see
# how 3 datasets are related to each other
# 3 dataset have anything in common & can be concatenated or merged

# %%
data1 = pd.read_csv(r'C:\Users\Administrator\Class Notebooks\Datasets\StoreData\Features data set.csv')

# %%
data1
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
data3
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 0           1     1 2010-05-02      24924.50      False
# 1           1     1 2010-12-02      46039.49       True
# 2           1     1 2010-02-19      41595.55      False
# 3           1     1 2010-02-26      19403.54      False
# 4           1     1 2010-05-03      21827.90      False
# ...       ...   ...        ...           ...        ...
# 421565     45    98 2012-09-28        508.37      False
# 421566     45    98 2012-05-10        628.10      False
# 421567     45    98 2012-12-10       1061.02      False
# 421568     45    98 2012-10-19        760.01      False
# 421569     45    98 2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
#data1[data1['Date']=='05/02/2010']['Store'].value_counts()

# %%
data1['Date']=pd.to_datetime(data1['Date'])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   datetime64[ns]
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1)
# memory usage: 712.0 KB

# %%
# Default
#data1.describe(include = [np.number])
# To include datetime
#data1.describe(datetime_is_numeric= True)
#data1.describe(include=['datetime'], datetime_is_numeric=True)

# %%
data1.describe(include='all',datetime_is_numeric=True).T
# Out:
#              count unique    top  freq                           mean  \
# Store         8190    NaN    NaN   NaN                             23
# Date          8190    NaN    NaN   NaN  2011-11-04 13:19:07.252744448
# Temperature   8190    NaN    NaN   NaN                        59.3562
# Fuel_Price    8190    NaN    NaN   NaN                        3.40599
# MarkDown1     4032    NaN    NaN   NaN                        7032.37
# MarkDown2     2921    NaN    NaN   NaN                        3384.18
# MarkDown3     3613    NaN    NaN   NaN                         1760.1
# MarkDown4     3464    NaN    NaN   NaN                        3292.94
# MarkDown5     4050    NaN    NaN   NaN                        4132.22
# CPI           7605    NaN    NaN   NaN                        172.461
# Unemployment  7605    NaN    NaN   NaN                        7.82682
# IsHoliday     8190      2  False  7605                            NaN
#
# ...

# %%
# As per Features dataset - 
# data for 45 stores
# We have date from 10-01-2011 to 07-12-2013
# We have nulls - MarkDown1,2,3,4,5 CPI & Unemployment

# %%
data2 = pd.read_csv(r'C:\Users\Administrator\Class Notebooks\Datasets\StoreData\stores data-set.csv')

# %%
data2
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# ..    ...  ...     ...
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221
#
# [45 rows x 3 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
data2.describe(include='all').T
# Out:
#       count unique  top freq    mean      std    min    25%     50%     75%  \
# Store    45    NaN  NaN  NaN      23  13.1339      1     12      23      34
# Type     45      3    A   22     NaN      NaN    NaN    NaN     NaN     NaN
# Size     45    NaN  NaN  NaN  130288  63825.3  34875  70713  126512  202307
#
#           max
# Store      45
# Type      NaN
# Size   219622

# %%
# We have Stores from 1 to 45
# All stores have only one type A or B or C
# Stores have different areas

# %%
data3 = pd.read_csv(r'C:\Users\Administrator\Class Notebooks\Datasets\StoreData\sales data-set.csv')

# %%
data3['Date']=pd.to_datetime(data3['Date'])

# %%
data3
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 0           1     1 2010-05-02      24924.50      False
# 1           1     1 2010-12-02      46039.49       True
# 2           1     1 2010-02-19      41595.55      False
# 3           1     1 2010-02-26      19403.54      False
# 4           1     1 2010-05-03      21827.90      False
# ...       ...   ...        ...           ...        ...
# 421565     45    98 2012-09-28        508.37      False
# 421566     45    98 2012-05-10        628.10      False
# 421567     45    98 2012-12-10       1061.02      False
# 421568     45    98 2012-10-19        760.01      False
# 421569     45    98 2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
#data3[data3['Date']=='2010-05-02']['Store'].value_counts()

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2)
# memory usage: 13.3 MB

# %%
data3.describe(include='all', datetime_is_numeric=True).T
# Out:
#                count unique    top    freq                           mean  \
# Store         421570    NaN    NaN     NaN                        22.2005
# Dept          421570    NaN    NaN     NaN                        44.2603
# Date          421570    NaN    NaN     NaN  2011-06-19 05:35:51.734504960
# Weekly_Sales  421570    NaN    NaN     NaN                        15981.3
# IsHoliday     421570      2  False  391909                            NaN
#
#                               min                  25%                  50%  \
# Store                           1                   11                   22
# Dept                            1                   18                   37
# Date          2010-01-10 00:00:00  2010-10-12 00:00:00  2011-06-17 00:00:00
# Weekly_Sales             -4988.94              2079.65              7612.03
# IsHoliday                     NaN                  NaN                  NaN
#
#                               75%                  max      std
# ...

# %%
# Sales data
# All stores are segregated into different departments of 99 different depts
# Date range is from 10-01-2011 to 10-12-2012
# for data1 -  We have date from 10-01-2011 to 07-12-2013
# We ahve weekly sales - for store & Dept wise
# We can have good line plot for Sales for each store type, summarised
# Any impact of holiday on the sales

# %%
# By looking at the 3 different datasets 
# Dataset 3 - Sales data is most important as it gives me weekly Sales figure for different stores & depts & store types
# Dataset 2  - Sotes data just defines the stores 
# Dataset 1 - Need more analysis required to understand the dataset better also, need to understand markdowns

# %%
# I will start from dataset 2 so that I can club that dataset with other two datasets

# %%
data2
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# ..    ...  ...     ...
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221
#
# [45 rows x 3 columns]

# %%
# Also, we need to segregate store types with sotes
# Count of types - count plot
# Bar Chat Type A & Size ot understand are & store type
# line chart between type & size

# %%
data2['Type'].value_counts()
# Out:
# A    22
# B    17
# C     6
# Name: Type, dtype: int64

# %%
pd.set_option('precision', 2)
pd.pivot_table(data2, index='Type', values='Size')
# Out:
#            Size
# Type
# A     177247.73
# B     101190.71
# C      40541.67

# %%
data2.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
pd.set_option('precision', 2)
pd.pivot_table(data2, index='Type', values='Size', aggfunc=('count','mean'))
# We have maximm number of A stores with average size of 177247 max size
# Type B count is 17 & size is 101190
# Least type C stores with least average area of  40541
# Out:
#       count       mean
# Type
# A      22.0  177247.73
# B      17.0  101190.71
# C       6.0   40541.67

# %%
sns.countplot(x = 'Type', data = data2)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.barplot(x = 'Type',y = 'Size',data = data2)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Size'>

# %%
plt.figure(figsize= (10,10))
sns.boxplot(y = 'Type',x = 'Size',data = data2)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Type'>

# %%
data2[data2['Type']=='C']
# Out:
#     Store Type   Size
# 29     30    C  42988
# 36     37    C  39910
# 37     38    C  39690
# 41     42    C  39690
# 42     43    C  41062
# 43     44    C  39910

# %%
data2[data2['Type']=='C']
# Out:
#     Store Type   Size
# 29     30    C  42988
# 36     37    C  39910
# 37     38    C  39690
# 41     42    C  39690
# 42     43    C  41062
# 43     44    C  39910

# %%
# Careful about the quotations
data2.query("Type=='C'")
# Out:
#     Store Type   Size
# 29     30    C  42988
# 36     37    C  39910
# 37     38    C  39690
# 41     42    C  39690
# 42     43    C  41062
# 43     44    C  39910

# %%
sns.boxplot(x = 'Type',y = 'Size', data = data2[data2['Type']=='C'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Size'>

# %%
sns.histplot(x='Size', data = data2, bins=50, hue='Type')
# We have over lapping for area B & C
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Count'>

# %%
sns.histplot(x='Size',y ='Type', data = data2, bins=50, hue = 'Type')
# We have over lapping for area A, B & C
# for each Store type we have to find out max & min area to find out if there exist any correlation
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Type'>

# %%
# pd.set_option('precision', 2)
pd.pivot_table(data2, index='Type', values='Size', aggfunc=('count','mean','min','max'))
# By looking at the min & max areas looks like there is no segregation of store type by area size but
# It we need to check with the business on this becasue except for one values rest shows that type A has max area
# & type C has least areas
# Same thing is confirmed by boxplots & outliers
# Out:
#       count       max       mean      min
# Type
# A      22.0  219622.0  177247.73  39690.0
# B      17.0  140167.0  101190.71  34875.0
# C       6.0   42988.0   40541.67  39690.0

# %%
data3
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 0           1     1 2010-05-02      24924.50      False
# 1           1     1 2010-12-02      46039.49       True
# 2           1     1 2010-02-19      41595.55      False
# 3           1     1 2010-02-26      19403.54      False
# 4           1     1 2010-05-03      21827.90      False
# ...       ...   ...        ...           ...        ...
# 421565     45    98 2012-09-28        508.37      False
# 421566     45    98 2012-05-10        628.10      False
# 421567     45    98 2012-12-10       1061.02      False
# 421568     45    98 2012-10-19        760.01      False
# 421569     45    98 2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
data3.describe()
# Out:
#            Store       Dept  Weekly_Sales
# count  421570.00  421570.00     421570.00
# mean       22.20      44.26      15981.26
# std        12.79      30.49      22711.18
# min         1.00       1.00      -4988.94
# 25%        11.00      18.00       2079.65
# 50%        22.00      37.00       7612.03
# 75%        33.00      74.00      20205.85
# max        45.00      99.00     693099.36

# %%
# Weekly sales line plot for date
# Weekly sales lineplot for Store & Dept
# Store & Dept relationship & count
# Impact of holiday on weekly sales
# Ranking - Sorted - Weekly Sales for Store & Dept

# %%
pd.pivot_table(data = data3, index=('Store','Dept'),values = 'Weekly_Sales', aggfunc=('mean','min','max'))
# Out:
#                  max      mean       min
# Store Dept
# 1     1     57592.12  22513.32  14537.37
#       2     65615.36  46102.09  35819.83
#       3     51159.17  13150.48   6165.73
#       4     47893.23  36964.15  32497.43
#       5     85676.09  24257.94  11570.27
# ...              ...       ...       ...
# 45    94     7639.88   3690.27      0.98
#       95    75204.77  52896.17  41131.42
#       96        3.00      2.97      2.94
#       97     8765.09   6466.96   4935.60
#       98     1504.71    561.24      2.00
#
# [3331 rows x 3 columns]

# %%
pd.pivot_table(data = data3, index=('Store'),values = 'Weekly_Sales', aggfunc=('mean','min','max'))
# Out:
#              max      mean      min
# Store
# 1      203670.47  21710.54  -863.00
# 2      285353.53  26898.07 -1098.00
# 3      155897.94   6373.03 -1008.96
# 4      385051.04  29161.21  -898.00
# 5       93517.72   5053.42  -101.26
# ...          ...       ...      ...
# 41     290809.17  17976.00  -279.00
# 42     112152.35  11443.37  -379.00
# 43     108517.42  13415.11  -372.90
# 44      66629.98   6038.93  -132.46
# 45     240758.86  11662.90 -1750.00
#
# [45 rows x 3 columns]

# %%
#data3.query('Store == 1')

# %%
pd.pivot_table(data = data3, index=('Store'),values = 'Weekly_Sales', 
               aggfunc=('mean','min','max')).sort_values(by = 'mean', ascending=False)
# Out:
#              max      mean      min
# Store
# 20     422306.25  29508.30  -798.00
# 4      385051.04  29161.21  -898.00
# 14     474330.10  28784.85  -498.00
# 13     292165.78  27355.14   -98.00
# 2      285353.53  26898.07 -1098.00
# ...          ...       ...      ...
# 38     100618.04   7492.48  -153.12
# 3      155897.94   6373.03 -1008.96
# 44      66629.98   6038.93  -132.46
# 33      49129.77   5728.41   -39.76
# 5       93517.72   5053.42  -101.26
#
# [45 rows x 3 columns]

# %%
plt.figure(figsize = (15,10))
sns.barplot(x = 'Store',y = 'Weekly_Sales', data = data3)
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
#plt.figure(figsize = (20,10))
#sns.barplot(x = 'Store',y = 'Weekly_Sales', data = data3, hue='IsHoliday', palette='bright')

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = 'Store',y = 'Weekly_Sales', data = data3, hue = 'IsHoliday', palette={True:'#ffd56b', False:'#ff7b54'})
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
data4 = data3.sort_values(by = 'Weekly_Sales')

# %%
data4
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 267730     28     6 2010-08-10      -4988.94      False
# 336495     35    47 2011-02-09      -3924.00      False
# 417801     45    47 2010-02-26      -1750.00      False
# 153916     16    47 2012-09-03      -1699.00      False
# 271300     28    32 2011-03-25      -1321.48      False
# ...       ...   ...        ...           ...        ...
# 135665     14    72 2010-11-26     474330.10       True
# 337961     35    72 2010-11-26     627962.93       True
# 95425      10    72 2011-11-25     630999.19       True
# 338013     35    72 2011-11-25     649770.18       True
# 95373      10    72 2010-11-26     693099.36       True
#
# [421570 rows x 5 columns]

# %%
#pd.set_option('display.float_format', '{:.2f}'.format)
#data4 = data3.groupby(["Store"])['Weekly_Sales'].aggregate(np.mean).reset_index().sort_values('Weekly_Sales')

# %%
#plt.figure(figsize = (15,10))
#sns.barplot(x = 'Store',y = 'Weekly_Sales', data = data3, order = data4['Store'])

# %%
#pd.set_option('display.float_format', '{:.2f}'.format)
#data5 = data3.groupby(["Store"])['Weekly_Sales'].aggregate(np.sum).reset_index().sort_values('Weekly_Sales')

# %%
 data6= pd.pivot_table(data3, index='Store',values='Weekly_Sales',aggfunc='sum').sort_values('Weekly_Sales')

# %%
data6
# Out:
#        Weekly_Sales
# Store
# 33      37160221.96
# 44      43293087.84
# 5       45475688.90
# 36      53412214.97
# 38      55159626.42
# ...             ...
# 2      275382440.98
# 13     286517703.80
# 14     288999911.34
# 4      299543953.38
# 20     301397792.46
#
# [45 rows x 1 columns]

# %%
plt.figure(figsize = (15,10))
sns.barplot(x = data6.index,y = 'Weekly_Sales', data = data6, order = data6.index)
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
data3
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 0           1     1 2010-05-02      24924.50      False
# 1           1     1 2010-12-02      46039.49       True
# 2           1     1 2010-02-19      41595.55      False
# 3           1     1 2010-02-26      19403.54      False
# 4           1     1 2010-05-03      21827.90      False
# ...       ...   ...        ...           ...        ...
# 421565     45    98 2012-09-28        508.37      False
# 421566     45    98 2012-05-10        628.10      False
# 421567     45    98 2012-12-10       1061.02      False
# 421568     45    98 2012-10-19        760.01      False
# 421569     45    98 2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data3)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Weekly_Sales'>

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data3.query("Store==20"))
# Average Weekly sales is more for winter months
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Weekly_Sales'>

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data3.query("Store==40"))
# Average Weekly sales is more for winter months
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Weekly_Sales'>

# %%
data7 = data3[(data3['Date']>='2010-09-01') & (data3['Date']<='2011-03-01')]

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data7.query("Store==20"), hue = 'Store')
# Average Weekly sales is more for winter months
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Weekly_Sales'>

# %%
# data7.query("Store in (10,20)")

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data7.query("Store in (33,20)"), hue = 'Store')
# Average Weekly sales is more for winter months
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Weekly_Sales'>

# %%
data8 = data3[(data3['Date']>='2011-01-01') & (data3['Date']<='2011-02-01') & (data3['Store']==20)]

# %%
data8.shape
# Out:
# (357, 5)

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data8.query("Store==20"), hue = 'Store')
# Average Weekly sales is more for winter months
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Weekly_Sales'>

# %%
plt.figure(figsize = (15,7))
ax = sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data8, hue = 'Store')
ax.set(xticks=data8.Date.values)
plt.show()

# %%
data9 = data3[(data3['Date']>='2010-10-01') & (data3['Date']<='2010-10-18') & (data3['Store']==20)]

# %%
data9.shape, data9.head()
# Out:
# ((216, 5),
#          Store  Dept       Date  Weekly_Sales  IsHoliday
#  187366     20     1 2010-10-09      35321.83       True
#  187371     20     1 2010-10-15      51450.76      False
#  187379     20     1 2010-10-12      75751.30      False
#  187509     20     2 2010-10-09      79303.26       True
#  187514     20     2 2010-10-15      75347.76      False)

# %%
plt.figure(figsize = (15,7))
ax = sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data9, hue = 'IsHoliday')

# %%
plt.figure(figsize = (15,7))
ax = sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data9)

# %%
data3_dt = data3.sort_index()

# %%
data3_dt['Date'].dt.isocalendar().year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 421565    2012
# 421566    2012
# 421567    2012
# 421568    2012
# 421569    2012
# Name: year, Length: 421570, dtype: UInt32

# %%
data3_dt['Date'].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 421565    2012
# 421566    2012
# 421567    2012
# 421568    2012
# 421569    2012
# Name: Date, Length: 421570, dtype: int64

# %%
data3_dt['Date'].dt.month
# Out:
# 0          5
# 1         12
# 2          2
# 3          2
# 4          5
#           ..
# 421565     9
# 421566     5
# 421567    12
# 421568    10
# 421569    10
# Name: Date, Length: 421570, dtype: int64

# %%
plt.figure(figsize = (15,7))
sns.lineplot(x = 'Date',y = 'Weekly_Sales', data = data3)
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 187366     20     1 2010-10-09      35321.83       True
# 187371     20     1 2010-10-15      51450.76      False
# 187379     20     1 2010-10-12      75751.30      False
# 187509     20     2 2010-10-09      79303.26       True
# 187514     20     2 2010-10-15      75347.76      False

# %%
data9['Date'].duplicated().sum()
# Out:
# 213

# %%
data9['Date'].value_counts()
# Out:
# 2010-10-09    72
# 2010-10-12    72
# 2010-10-15    72
# Name: Date, dtype: int64

# %% [markdown]
# # Mergeds Datasets Analysis

# %%
data1.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
data2.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
data3.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   datetime64[ns]
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1)
# memory usage: 712.0 KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2)
# memory usage: 13.3 MB

# %%
data3.query("Store==1")
# Out:
#        Store  Dept       Date  Weekly_Sales  IsHoliday
# 0          1     1 2010-05-02      24924.50      False
# 1          1     1 2010-12-02      46039.49       True
# 2          1     1 2010-02-19      41595.55      False
# 3          1     1 2010-02-26      19403.54      False
# 4          1     1 2010-05-03      21827.90      False
# ...      ...   ...        ...           ...        ...
# 10239      1    99 2012-08-31         20.06      False
# 10240      1    99 2012-07-09          0.05       True
# 10241      1    99 2012-09-14          0.03      False
# 10242      1    99 2012-05-10        635.00      False
# 10243      1    99 2012-12-10         80.00      False
#
# [10244 rows x 5 columns]

# %%
data1.query("Date=='05/02/2010'")
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1 2010-05-02        42.31       2.572        NaN        NaN
# 182       2 2010-05-02        40.19       2.572        NaN        NaN
# 364       3 2010-05-02        45.71       2.572        NaN        NaN
# 546       4 2010-05-02        43.76       2.598        NaN        NaN
# 728       5 2010-05-02        39.70       2.572        NaN        NaN
# ...     ...        ...          ...         ...        ...        ...
# 7280     41 2010-05-02        30.27       2.580        NaN        NaN
# 7462     42 2010-05-02        54.34       2.962        NaN        NaN
# 7644     43 2010-05-02        47.31       2.572        NaN        NaN
# 7826     44 2010-05-02        31.53       2.666        NaN        NaN
# 8008     45 2010-05-02        27.31       2.784        NaN        NaN
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
data3.query("Date=='05/02/2010'")
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday
# 0           1     1 2010-05-02      24924.50      False
# 143         1     2 2010-05-02      50605.27      False
# 286         1     3 2010-05-02      13740.12      False
# 429         1     4 2010-05-02      39954.04      False
# 572         1     5 2010-05-02      32229.38      False
# ...       ...   ...        ...           ...        ...
# 420727     45    92 2010-05-02      68203.08      False
# 420870     45    93 2010-05-02       4002.34      False
# 421147     45    95 2010-05-02      63833.63      False
# 421292     45    97 2010-05-02       8393.22      False
# 421435     45    98 2010-05-02        347.23      False
#
# [2955 rows x 5 columns]

# %%
df3 = data3.query("Date=='05/02/2010'")

# %%
df3[df3['Store']==1].value_counts()
# Out:
# Store  Dept  Date        Weekly_Sales  IsHoliday
# 1      98    2010-05-02  10891.37      False        1
#        37    2010-05-02  3438.16       False        1
#        21    2010-05-02  8907.63       False        1
#        22    2010-05-02  13623.98      False        1
#        23    2010-05-02  24146.49      False        1
#                                                    ..
#        54    2010-05-02  439.00        False        1
#        55    2010-05-02  21249.31      False        1
#        56    2010-05-02  2567.36       False        1
#        58    2010-05-02  7659.97       False        1
#        1     2010-05-02  24924.50      False        1
# Length: 73, dtype: int64

# %%
pd.set_option('display.max_rows',50)

df3['Store'].value_counts(ascending=True)
# Out:
# 36    38
# 33    40
# 42    46
# 43    48
# 44    48
# 37    49
# 38    51
# 30    52
# 9     62
# 5     62
# 3     65
# 16    65
# 21    66
# 29    66
# 45    67
# 25    67
# 22    67
# 35    67
# 18    67
# 39    68
# 15    69
# 8     69
# 26    69
# 40    69
# 12    70
# 27    70
# 17    70
# 41    71
# 14    71
# 28    72
# 11    72
# 24    72
# 19    72
# 23    72
# 32    72
# 7     72
# 31    73
# 2     73
# 20    73
# 6     73
# 4     73
# 1     73
# 34    74
# 10    75
# 13    75
# Name: Store, dtype: int64

# %%
df3['Store'].value_counts().reset_index().sort_values('index')
# Out:
#     index  Store
# 3       1     73
# 7       2     73
# 34      3     65
# 4       4     73
# 35      5     62
# 5       6     73
# 9       7     72
# 23      8     69
# 36      9     62
# 1      10     75
# 14     11     72
# 20     12     70
# 0      13     75
# 16     14     71
# 24     15     69
# 33     16     65
# 18     17     70
# 26     18     67
# 12     19     72
# 6      20     73
# 32     21     66
# 28     22     67
# 11     23     72
# 13     24     72
# 29     25     67
# 22     26     69
# 19     27     70
# 15     28     72
# 31     29     66
# 37     30     52
# 8      31     73
# 10     32     72
# 43     33     40
# 2      34     74
# 27     35     67
# 44     36     38
# 39     37     49
# 38     38     51
# 25     39     68
# 21     40     69
# 17     41     71
# 42     42     46
# 41     43     48
# 40     44     48
# 30     45     67

# %%
df3.groupby(['Store']).size()
# Out:
# Store
# 1     73
# 2     73
# 3     65
# 4     73
# 5     62
#       ..
# 41    71
# 42    46
# 43    48
# 44    48
# 45    67
# Length: 45, dtype: int64

# %%
data_date = data1.groupby("Date").agg({"Temperature":"mean"
                                            ,"Fuel_Price":"mean"
                                            ,"IsHoliday":"sum"
                                            ,"CPI":"mean"
                                           ,"Unemployment":"mean"})

# %%
data_feature_sm = pd.pivot_table(data = data1, index  = 'Date', aggfunc=({"Temperature":"mean"
                                            ,"Fuel_Price":"mean"
                                            ,"IsHoliday":"sum"
                                            ,"CPI":"mean"
                                           ,"Unemployment":"mean"}))

# %%
data_feature_sm
# Out:
#                    CPI  Fuel_Price  IsHoliday  Temperature  Unemployment
# Date
# 2010-01-10  168.354706    2.734333          0    69.868000      8.475289
# 2010-02-04  167.789036    2.827333          0    53.120889      8.497711
# 2010-02-07  167.982101    2.793511          0    77.133333      8.428578
# 2010-02-19  167.871686    2.672067          0    37.719778      8.619311
# 2010-02-26  167.909657    2.683933          0    39.243556      8.619311
# ...                ...         ...        ...          ...           ...
# 2013-08-03  177.672434    3.775711          0    44.889111      6.876444
# 2013-10-05         NaN    3.542822          0    62.092444           NaN
# 2013-11-01  177.235667    3.377489          0    38.091556      6.876444
# 2013-12-04  177.990680    3.671044          0    55.050222      6.719244
# 2013-12-07         NaN    3.568111          0    80.798667           NaN
#
# [182 rows x 5 columns]

# %%
data_feature_sm['IsHoliday'].value_counts()
# Out:
# 0     169
# 45     13
# Name: IsHoliday, dtype: int64

# %%
data

# %%
data_date = data_date.sort_index()

# %%
data_date
# Out:
#             Temperature  Fuel_Price  IsHoliday         CPI  Unemployment
# Date
# 2010-01-10    69.868000    2.734333          0  168.354706      8.475289
# 2010-02-04    53.120889    2.827333          0  167.789036      8.497711
# 2010-02-07    77.133333    2.793511          0  167.982101      8.428578
# 2010-02-19    37.719778    2.672067          0  167.871686      8.619311
# 2010-02-26    39.243556    2.683933          0  167.909657      8.619311
# ...                 ...         ...        ...         ...           ...
# 2013-08-03    44.889111    3.775711          0  177.672434      6.876444
# 2013-10-05    62.092444    3.542822          0         NaN           NaN
# 2013-11-01    38.091556    3.377489          0  177.235667      6.876444
# 2013-12-04    55.050222    3.671044          0  177.990680      6.719244
# 2013-12-07    80.798667    3.568111          0         NaN           NaN
#
# [182 rows x 5 columns]

# %%
temp_date_data = data_date[:'2012-12-10']
temp_date_data
# Out:
#             Temperature  Fuel_Price  IsHoliday         CPI  Unemployment
# Date
# 2010-01-10    69.868000    2.734333          0  168.354706      8.475289
# 2010-02-04    53.120889    2.827333          0  167.789036      8.497711
# 2010-02-07    77.133333    2.793511          0  167.982101      8.428578
# 2010-02-19    37.719778    2.672067          0  167.871686      8.619311
# 2010-02-26    39.243556    2.683933          0  167.909657      8.619311
# ...                 ...         ...        ...         ...           ...
# 2012-11-05    64.838000    3.869689          0  175.626366      7.419533
# 2012-11-16    47.114444    3.549289          0  176.655161      6.953711
# 2012-11-23    49.637778    3.526311         45  176.687192      6.953711
# 2012-11-30    45.773333    3.502067          0  176.719224      6.953711
# 2012-12-10    58.342667    3.896733          0  176.636515      6.953711
#
# [149 rows x 5 columns]

# %%
data_sales_date = data3.groupby("Date").agg({"Weekly_Sales":"sum"})
data_sales_date
# Out:
#             Weekly_Sales
# Date
# 2010-01-10   42239875.87
# 2010-02-04   50423831.26
# 2010-02-07   48917484.50
# 2010-02-19   48276993.78
# 2010-02-26   43968571.13
# ...                  ...
# 2012-10-08   47403451.04
# 2012-10-19   45122410.57
# 2012-10-26   45544116.29
# 2012-11-05   46925878.99
# 2012-12-10   46128514.25
#
# [143 rows x 1 columns]

# %%
data_sales_sm = pd.pivot_table(data3, index='Date', values='Weekly_Sales', aggfunc=({'Weekly_Sales':'sum'}))

# %%
data_sales_sm
# Out:
#             Weekly_Sales
# Date
# 2010-01-10   42239875.87
# 2010-02-04   50423831.26
# 2010-02-07   48917484.50
# 2010-02-19   48276993.78
# 2010-02-26   43968571.13
# ...                  ...
# 2012-10-08   47403451.04
# 2012-10-19   45122410.57
# 2012-10-26   45544116.29
# 2012-11-05   46925878.99
# 2012-12-10   46128514.25
#
# [143 rows x 1 columns]

# %%
data_sales_sm.Weekly_Sales =data_sales_sm.Weekly_Sales/1000000

# %%
data_sales_sm
# Out:
#             Weekly_Sales
# Date
# 2010-01-10     42.239876
# 2010-02-04     50.423831
# 2010-02-07     48.917485
# 2010-02-19     48.276994
# 2010-02-26     43.968571
# ...                  ...
# 2012-10-08     47.403451
# 2012-10-19     45.122411
# 2012-10-26     45.544116
# 2012-11-05     46.925879
# 2012-12-10     46.128514
#
# [143 rows x 1 columns]

# %%
data_sales_sm.Weekly_Sales = data_sales_sm.Weekly_Sales.apply(int)

# %%
data_sales_sm
# Out:
#             Weekly_Sales
# Date
# 2010-01-10            42
# 2010-02-04            50
# 2010-02-07            48
# 2010-02-19            48
# 2010-02-26            43
# ...                  ...
# 2012-10-08            47
# 2012-10-19            45
# 2012-10-26            45
# 2012-11-05            46
# 2012-12-10            46
#
# [143 rows x 1 columns]

# %%
data = pd.merge(data_sales_sm, temp_date_data, left_index=True,right_index=True, how='left')

# %%
data
# Out:
#             Weekly_Sales  Temperature  Fuel_Price  IsHoliday         CPI  \
# Date
# 2010-01-10            42    69.868000    2.734333          0  168.354706
# 2010-02-04            50    53.120889    2.827333          0  167.789036
# 2010-02-07            48    77.133333    2.793511          0  167.982101
# 2010-02-19            48    37.719778    2.672067          0  167.871686
# 2010-02-26            43    39.243556    2.683933          0  167.909657
# ...                  ...          ...         ...        ...         ...
# 2012-10-08            47    81.580222    3.632911          0  175.689620
# 2012-10-19            45    60.705333    3.880000          0  176.652613
# 2012-10-26            45    61.051111    3.791489          0  176.649482
# 2012-11-05            46    64.838000    3.869689          0  175.626366
# 2012-12-10            46    58.342667    3.896733          0  176.636515
#
#             Unemployment
# Date
# 2010-01-10      8.475289
# 2010-02-04      8.497711
# ...

# %%
data["IsHoliday"] = data["IsHoliday"].apply(lambda x: True if x == 45.0 else False )

# %%
data.describe().T
# Out:
#               count        mean        std         min         25%  \
# Weekly_Sales  143.0   46.601399   5.399713   39.000000   44.000000
# Temperature   143.0   60.663782  15.172792   30.480889   47.720222
# Fuel_Price    143.0    3.358607   0.429401    2.672067    2.885367
# CPI           143.0  171.578394   3.100148  167.546485  168.408144
# Unemployment  143.0    7.999151   0.483853    6.953711    7.508333
#
#                      50%         75%         max
# Weekly_Sales   46.000000   47.000000   80.000000
# Temperature    61.051111   74.697333   82.176444
# Fuel_Price      3.488644    3.726133    3.997778
# CPI           171.386189  174.724576  176.652613
# Unemployment    8.150133    8.428578    8.619311

# %%
data.corr()
# Out:
#               Weekly_Sales  Temperature  Fuel_Price  IsHoliday       CPI  \
# Weekly_Sales      1.000000    -0.154919   -0.057318   0.178288  0.030604
# Temperature      -0.154919     1.000000    0.205757  -0.189186  0.159457
# Fuel_Price       -0.057318     0.205757    1.000000  -0.084039  0.824704
# IsHoliday         0.178288    -0.189186   -0.084039   1.000000 -0.027542
# CPI               0.030604     0.159457    0.824704  -0.027542  1.000000
# Unemployment     -0.005560    -0.168460   -0.747205   0.042639 -0.977430
#
#               Unemployment
# Weekly_Sales     -0.005560
# Temperature      -0.168460
# Fuel_Price       -0.747205
# IsHoliday         0.042639
# CPI              -0.977430
# Unemployment      1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>
