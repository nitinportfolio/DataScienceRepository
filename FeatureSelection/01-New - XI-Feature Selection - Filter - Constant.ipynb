# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.feature_selection import VarianceThreshold

# %%
df = pd.read_csv('../featdata/home_credit.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 361 entries, EXT_SOURCE_1 to SK_ID_CURR
# dtypes: float64(325), int64(36)
# memory usage: 847.0 MB

# %%
df.shape
# Out:
# (307511, 361)

# %%
df.dtypes.value_counts()
# Out:
# float64    325
# int64       36
# dtype: int64

# %%
# As we have only numeric data we will use VarianceThreshold from sklearn to remove constants

# %%
# We will not split the data into train & test as we are already working with the training data

# %%
df.head()
# Out:
#    EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# 0      0.083037      0.262949      0.139376
# 1      0.311267      0.622246           NaN
# 2           NaN      0.555912      0.729567
# 3           NaN      0.650442           NaN
# 4           NaN      0.322738           NaN
#
#    client_installments_AMT_PAYMENT_min_sum  DAYS_BIRTH  AMT_CREDIT  \
# 0                               175783.725       -9461    406597.5
# 1                              1154108.295      -16765   1293502.5
# 2                                16071.750      -19046    135000.0
# 3                               994476.690      -19005    312682.5
# 4                               483756.390      -19932    513000.0
#
#    AMT_ANNUITY  DAYS_EMPLOYED  bureau_DAYS_CREDIT_ENDDATE_max  \
# 0      24700.5           -637                           780.0
# 1      35698.5          -1188                          1216.0
# 2       6750.0           -225                          -382.0
# ...

# %%
sel = VarianceThreshold()
sel.fit(df) # fit finds the features with zero variance
# Out:
# VarianceThreshold()

# %%
# get_support is a boolean vector that indicates which features are retained
# if we sum over get_support, we get the number of features that are not constant


sum(sel.get_support())
# Out:
# 361

# %%
len(df.columns) - sum(sel.get_support())
# Out:
# 0
