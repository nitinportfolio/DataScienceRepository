# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series

# %%
# Series - Series is similar to numpy arrays except that we can label the index in series.

# %%
mydata = [10,20,30,40,50]
mylabels = ['L1','L2','L3','L4','L5']

# %%
mylabels
# Out:
# ['L1', 'L2', 'L3', 'L4', 'L5']

# %%
mydata
# Out:
# [10, 20, 30, 40, 50]

# %%
mylabels
# Out:
# ['L1', 'L2', 'L3', 'L4', 'L5']

# %%
# Creating a series using list

# %%
myser = pd.Series(mydata)

# %%
myser
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# Creating a series with labeled index

# %%
myser = pd.Series(mydata, index=mylabels )

# %%
myser
# Out:
# L1    10
# L2    20
# L3    30
# L4    40
# L5    50
# dtype: int64

# %%
# Create a series with 
# data = 1000, 750, 400, 1200, 2500
# labels = mobilephone, headphone, earphone, hometheatre, laptop

# %%
# Creating a series using numpy array

# %%
myarr = np.array(mydata)

# %%
myarr
# Out:
# array([10, 20, 30, 40, 50])

# %%
myser = pd.Series(myarr)

# %%
myser
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
myser = pd.Series(myarr, mylabels)

# %%
myser
# Out:
# L1    10
# L2    20
# L3    30
# L4    40
# L5    50
# dtype: int32

# %%
myser
# Out:
# L1    10
# L2    20
# L3    30
# L4    40
# L5    50
# dtype: int32

# %%
myser[['L1','L4']]
# Out:
# L1    10
# L4    40
# dtype: int32

# %%
myser > 30
# Out:
# L1    False
# L2    False
# L3    False
# L4     True
# L5     True
# dtype: bool

# %%
myser[myser>30]
# Out:
# L4    40
# L5    50
# dtype: int32

# %%
type(myser)
# Out:
# pandas.core.series.Series

# %%
myser.dtype
# Out:
# dtype('int32')

# %%
# Creating Series using Dictionaries - System assign keys as labels automatically

# %%
price_dict = {
'laptop':1000,
'mobile':700,
'headphone':300
}

# %%
price_dict
# Out:
# {'laptop': 1000, 'mobile': 700, 'headphone': 300}

# %%
myser = pd.Series(price_dict)

# %%
myser
# Out:
# laptop       1000
# mobile        700
# headphone     300
# dtype: int64

# %%
book_store1 = pd.Series([5,10,0],['GOT','Harry Potter','Da Vinci Code'])
book_store2 = pd.Series([15,7,4],['GOT','Kite Runner','Da Vinci Code'])

# %%
book_store1 + book_store2
# Out:
# Da Vinci Code     4.0
# GOT              20.0
# Harry Potter      NaN
# Kite Runner       NaN
# dtype: float64

# %% [markdown]
# # DataFrames

# %%
mydata = np.array([[10,20,30],[40,50,60],[70,80,90]])
myrows = ['row1','row2','row3']
mycols = ['col1','col2','col3']

# %%
mydata
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
df = pd.DataFrame(mydata,index=myrows,columns = mycols)

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# create a car dataset

# %%
pwd
# Out:
# 'D:\\Users\\nitin'

# %%
import os

# %%
os.chdir('D:\\Users\\nitin\\datasets')

# %%
pwd
# Out:
# 'D:\\Users\\nitin\\datasets'

# %%
os.listdir()
# Out:
# ['cars.csv', 'Tele-Cust-Churn.csv']

# %%
os.getcwd()
# Out:
# 'D:\\Users\\nitin\\datasets'

# %%
cardf = pd.read_csv('D:\\Users\\nitin\\datasets\\cars.csv',index_col=0)

# %%
os.chdir('D:\\Users\\nitin')

# %%
pwd
# Out:
# 'D:\\Users\\nitin'

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
df['col1']
# Out:
# row1    10
# row2    40
# row3    70
# Name: col1, dtype: int32

# %%
type(df['col1'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['col1','col3']]
# Out:
#       col1  col3
# row1    10    30
# row2    40    60
# row3    70    90

# %%
# creating a new column

# %%
df['new_col'] = [10,20,30]

# %%
df
# Out:
#       col1  col2  col3  new_col
# row1    10    20    30       10
# row2    40    50    60       20
# row3    70    80    90       30

# %%
# in df.shape index 0 is 3 that is rows & index 1 is 4 that is columns 
df.shape
# Out:
# (3, 4)

# %%
# 0 = index, 1 = columns default is 0
df.drop('new_col',axis=1)
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
df
# Out:
#       col1  col2  col3  new_col
# row1    10    20    30       10
# row2    40    50    60       20
# row3    70    80    90       30

# %%
df.drop('new_col',axis=1, inplace=True)

# %%
df['newcol']=df['col1']*10 +df['col2']

# %%
df
# Out:
#       col1  col2  col3  newcol
# row1    10    20    30     120
# row2    40    50    60     450
# row3    70    80    90     780

# %%
df.drop('newcol', axis = 1, inplace = True)

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# Selecting rows
# 1 by location loc
# 2 by index iloc

# %%
df.loc['row1']
# Out:
# col1    10
# col2    20
# col3    30
# Name: row1, dtype: int32

# %%
df.loc[['row1','row3']]
# Out:
#       col1  col2  col3
# row1    10    20    30
# row3    70    80    90

# %%
df.iloc[['0','2']]
# Out:
#       col1  col2  col3
# row1    10    20    30
# row3    70    80    90

# %%
cardf
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
cardf.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
type(cardf)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       col1  col2  col3
# row1    10    20    30
# row2    40    50    60
# row3    70    80    90

# %%
# selecting 50
df.loc['row2']['col2']
# Out:
# 50

# %%
df[['col2','col3']]
# Out:
#       col2  col3
# row1    20    30
# row2    50    60
# row3    80    90

# %%
df.loc[['row2','row3']]
# Out:
#       col1  col2  col3
# row2    40    50    60
# row3    70    80    90

# %%
df.loc[['row2','row3'],['col2','col3']]
# Out:
#       col2  col3
# row2    50    60
# row3    80    90

# %%
# Conditional Selection

# %%
cardf
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
cardf.iloc[0:5][['mpg','cyl']]
# Out:
#                     mpg  cyl
# Mazda RX4          21.0    6
# Mazda RX4 Wag      21.0    6
# Datsun 710         22.8    4
# Hornet 4 Drive     21.4    6
# Hornet Sportabout  18.7    8

# %%
cardf.iloc[0:5][['mpg','hp']]
# Out:
#                     mpg   hp
# Mazda RX4          21.0  110
# Mazda RX4 Wag      21.0  110
# Datsun 710         22.8   93
# Hornet 4 Drive     21.4  110
# Hornet Sportabout  18.7  175

# %%
cardf.iloc[0:5][['mpg','hp']]
# Out:
#                     mpg   hp
# Mazda RX4          21.0  110
# Mazda RX4 Wag      21.0  110
# Datsun 710         22.8   93
# Hornet 4 Drive     21.4  110
# Hornet Sportabout  18.7  175

# %%
cardf.iloc[0:5]
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
cardf[cardf.columns[1:5]]
# Out:
#                      cyl   disp   hp  drat
# Mazda RX4              6  160.0  110  3.90
# Mazda RX4 Wag          6  160.0  110  3.90
# Datsun 710             4  108.0   93  3.85
# Hornet 4 Drive         6  258.0  110  3.08
# Hornet Sportabout      8  360.0  175  3.15
# Valiant                6  225.0  105  2.76
# Duster 360             8  360.0  245  3.21
# Merc 240D              4  146.7   62  3.69
# Merc 230               4  140.8   95  3.92
# Merc 280               6  167.6  123  3.92
# Merc 280C              6  167.6  123  3.92
# Merc 450SE             8  275.8  180  3.07
# Merc 450SL             8  275.8  180  3.07
# Merc 450SLC            8  275.8  180  3.07
# Cadillac Fleetwood     8  472.0  205  2.93
# Lincoln Continental    8  460.0  215  3.00
# Chrysler Imperial      8  440.0  230  3.23
# Fiat 128               4   78.7   66  4.08
# Honda Civic            4   75.7   52  4.93
# Toyota Corolla         4   71.1   65  4.22
# Toyota Corona          4  120.1   97  3.70
# Dodge Challenger       8  318.0  150  2.76
# AMC Javelin            8  304.0  150  3.15
# Camaro Z28             8  350.0  245  3.73
# Pontiac Firebird       8  400.0  175  3.08
# Fiat X1-9              4   79.0   66  4.08
# Porsche 914-2          4  120.3   91  4.43
# Lotus Europa           4   95.1  113  3.77
# Ford Pantera L         8  351.0  264  4.22
# Ferrari Dino           6  145.0  175  3.62
# Maserati Bora          8  301.0  335  3.54
# Volvo 142E             4  121.0  109  4.11

# %%
cardf.iloc[[1,2,4,6,-1]][cardf.columns[0:5]]
# Out:
#                     mpg  cyl   disp   hp  drat
# Mazda RX4 Wag      21.0    6  160.0  110  3.90
# Datsun 710         22.8    4  108.0   93  3.85
# Hornet Sportabout  18.7    8  360.0  175  3.15
# Duster 360         14.3    8  360.0  245  3.21
# Volvo 142E         21.4    4  121.0  109  4.11

# %%
cardf.iloc[0:10]
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2
# Valiant               1
# Duster 360            4
# Merc 240D             2
# Merc 230              2
# Merc 280              4

# %%
car = cardf.iloc[0:10]

# %%
# Look for all values greater than zero
car>0
# Out:
#                     mpg   cyl  disp    hp  drat    wt  qsec     vs     am  \
# Mazda RX4          True  True  True  True  True  True  True  False   True
# Mazda RX4 Wag      True  True  True  True  True  True  True  False   True
# Datsun 710         True  True  True  True  True  True  True   True   True
# Hornet 4 Drive     True  True  True  True  True  True  True   True  False
# Hornet Sportabout  True  True  True  True  True  True  True  False  False
# Valiant            True  True  True  True  True  True  True   True  False
# Duster 360         True  True  True  True  True  True  True  False  False
# Merc 240D          True  True  True  True  True  True  True   True  False
# Merc 230           True  True  True  True  True  True  True   True  False
# Merc 280           True  True  True  True  True  True  True   True  False
#
#                    gear  carb
# Mazda RX4          True  True
# Mazda RX4 Wag      True  True
# Datsun 710         True  True
# Hornet 4 Drive     True  True
# Hornet Sportabout  True  True
# Valiant            True  True
# Duster 360         True  True
# Merc 240D          True  True
# Merc 230           True  True
# Merc 280           True  True

# %%
# Will give NaN for which values are less than or equal to zero
car[car>0]
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec   vs   am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46  NaN  1.0     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02  NaN  1.0     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61  1.0  1.0     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44  1.0  NaN     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  NaN  NaN     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22  1.0  NaN     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84  NaN  NaN     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00  1.0  NaN     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90  1.0  NaN     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30  1.0  NaN     4
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2
# Valiant               1
# Duster 360            4
# Merc 240D             2
# Merc 230              2
# Merc 280              4

# %%
# selecting only cars that have milage greater than 20 
# car['mpg']
# car['mpg']>20
car[car['mpg']>20]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4       21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710      22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2

# %%
# Select only those cars that have am equal to zero

# %%
car[car['am']==0]
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb
# Hornet 4 Drive        1
# Hornet Sportabout     2
# Valiant               1
# Duster 360            4
# Merc 240D             2
# Merc 230              2
# Merc 280              4

# %%
df = car[car['am']==0]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# as df is again a dataframe we can apply same methods on it

# %%
df[df['mpg']>20]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2

# %%
# doing same thing in one line
# very complicated
car[car['am']==0][car[car['am']==0]['mpg']>20]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2

# %%
# Multiple conditions
(car['mpg']>20) & (car['am']==1)
# Out:
# Mazda RX4             True
# Mazda RX4 Wag         True
# Datsun 710            True
# Hornet 4 Drive       False
# Hornet Sportabout    False
# Valiant              False
# Duster 360           False
# Merc 240D            False
# Merc 230             False
# Merc 280             False
# dtype: bool

# %%
car[(car['mpg']>20) & (car['am']==1)]
# Out:
#                 mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4      21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710     22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
# for or use pipe operator
car[(car['mpg']>20) | (car['am']==1)]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4       21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710      22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2

# %%
# Index Reset - Will reset the index from 0 onwards and present index will be  a column

# %%
car.reset_index()
# Out:
#                index   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
car.reset_index()[['index','mpg']]
# Out:
#                index   mpg
# 0          Mazda RX4  21.0
# 1      Mazda RX4 Wag  21.0
# 2         Datsun 710  22.8
# 3     Hornet 4 Drive  21.4
# 4  Hornet Sportabout  18.7
# 5            Valiant  18.1
# 6         Duster 360  14.3
# 7          Merc 240D  24.4
# 8           Merc 230  22.8
# 9           Merc 280  19.2

# %%
df
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb
# Hornet 4 Drive        1
# Hornet Sportabout     2
# Valiant               1
# Duster 360            4
# Merc 240D             2
# Merc 230              2
# Merc 280              4

# %%
caralpha = ['a','b','c','d','e','f','g']

# %%
#'a b c d e f g'.split()

# %%
caralpha
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
# adding new columns

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df['altname'] = caralpha

# %%
newcol = ['a','b','c','d','e','f','g']

# %%
df.loc[:,'newname'] = newcol

# %%
df
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb altname newname
# Hornet 4 Drive        1       a       a
# Hornet Sportabout     2       b       b
# Valiant               1       c       c
# Duster 360            4       d       d
# Merc 240D             2       e       e
# Merc 230              2       f       f
# Merc 280              4       g       g

# %%
df.drop('altname',axis = 1, inplace = True)

# %%
df
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb newname
# Hornet 4 Drive        1       a
# Hornet Sportabout     2       b
# Valiant               1       c
# Duster 360            4       d
# Merc 240D             2       e
# Merc 230              2       f
# Merc 280              4       g

# %%
df.set_index('newname')
# Out:
#           mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# newname
# a        21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# b        18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# c        18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# d        14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# e        24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# f        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# g        19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4

# %%
df
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb newname
# Hornet 4 Drive        1       a
# Hornet Sportabout     2       b
# Valiant               1       c
# Duster 360            4       d
# Merc 240D             2       e
# Merc 230              2       f
# Merc 280              4       g

# %% [markdown]
# # Multi Index & Index Hierarchy

# %%
myindex = [('ClassA', 2000), ('ClassA', 2020),
         ('ClassB', 2000), ('ClassB', 2020),
         ('ClassC', 2000), ('ClassC', 2020)]

# %%
myindex
# Out:
# [('ClassA', 2000),
#  ('ClassA', 2020),
#  ('ClassB', 2000),
#  ('ClassB', 2020),
#  ('ClassC', 2000),
#  ('ClassC', 2020)]

# %%
students = [10, 30,15, 5,20, 50]

# %%
# Creating the MultiIndex 
no_class = pd.Series(students, index=myindex)

# %%
print(no_class)
# Out:
# (ClassA, 2000)    10
# (ClassA, 2020)    30
# (ClassB, 2000)    15
# (ClassB, 2020)     5
# (ClassC, 2000)    20
# (ClassC, 2020)    50
# dtype: int64

# %%
# better way of creating multiindiex

# %%
index = pd.MultiIndex.from_tuples(myindex)
index
# Out:
# MultiIndex([('ClassA', 2000),
#             ('ClassA', 2020),
#             ('ClassB', 2000),
#             ('ClassB', 2020),
#             ('ClassC', 2000),
#             ('ClassC', 2020)],
#            )

# %%
# Creating the MultiIndex 
newclass = pd.Series(students, index=index)

# %%
# 1st two shows the index and last one the data
newclass
# Out:
# ClassA  2000    10
#         2020    30
# ClassB  2000    15
#         2020     5
# ClassC  2000    20
#         2020    50
# dtype: int64

# %%
newclass['ClassB']
# Out:
# 2000    15
# 2020     5
# dtype: int64

# %%
no_class2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-251-55fe67d86a46> in <module>
# ----> 1 no_class2
#
# NameError: name 'no_class2' is not defined

# %%
new_class = no_class.reindex(index)

# %%
new_class

# %%
outter_index = ['G1','G1','G1','G2','G2','G2']
inner_index = [1,2,3,1,2,3]

# %%
hier_index = list(zip(outter_index,inner_index))

# %%
hier_index

# %%
hier_index_new = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index_new

# %%
from numpy.random import randn
df = pd.DataFrame(randn(6,2),hier_index_new,['A','B'])

# %%
df

# %%
myindex = [('ClassA', 2000), ('ClassA', 2020),
         ('ClassB', 2000), ('ClassB', 2020),
         ('ClassC', 2000), ('ClassC', 2020)]

# %%
students = [10, 30,15, 5,20, 50]

# %%
mult_index = pd.MultiIndex.from_tuples(myindex)

# %%
mult_index

# %%
students= [10, 100,15, 250,20, 150,30, 300,50, 150,20, 500]

# %%
students_arr = np.array(students).reshape(6,2)

# %%
students_arr

# %%
dfsch = pd.DataFrame(students_arr, mult_index, ['dps','mps'])

# %%
dfsch

# %%
# Selecting data from classA

# %%
dfsch.loc['ClassA']

# %%
dfsch.loc['ClassA'].loc[2020]

# %%
# Naming the indexs

# %%
dfsch.index.names=['Class','Year']

# %%
dfsch

# %%
# Selecting students

# %%
dfsch.loc['ClassB']

# %%
dfsch.loc['ClassB'].loc[2000]

# %%
dfsch.loc['ClassB'].loc[2000]['mps']

# %%
# Useful for stock index data
# CrossSection -

# %%
dfsch

# %%
# selecting data for year 2000 for all classes and all schools

# %%
dfsch.xs(2000,level = 'Year')

# %% [markdown]
# # Pandas - Missing Values

# %%
my_class = {
    'Bob':[90,95,np.nan],
    'Robin':[80,33,20],
    'Bill':[70,np.nan,np.nan]
}

# %%
my_class
# Out:
# {'Bob': [90, 95, nan], 'Robin': [80, 33, 20], 'Bill': [70, nan, nan]}

# %%
myclass = pd.DataFrame(my_class)

# %%
myclass
# Out:
#     Bob  Robin  Bill
# 0  90.0     80  70.0
# 1  95.0     33   NaN
# 2   NaN     20   NaN

# %%
# checking out nulls
myclass.isna()
# Out:
#      Bob  Robin   Bill
# 0  False  False  False
# 1  False  False   True
# 2   True  False   True

# %%
myclass.isna().sum()
# Out:
# Bob      1
# Robin    0
# Bill     2
# dtype: int64

# %%
#myclass.count()

# %%
#len(myclass)

# %%
#len(myclass)-myclass.count()

# %%
myclass.isnull()
# Out:
#      Bob  Robin   Bill
# 0  False  False  False
# 1  False  False   True
# 2   True  False   True

# %%
myclass.isnull().sum()
# Out:
# Bob      1
# Robin    0
# Bill     2
# dtype: int64

# %%
myclass.isnull().sum().sum()
# Out:
# 3

# %%
myclass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# Bob      2 non-null float64
# Robin    3 non-null int64
# Bill     1 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 200.0 bytes

# %%
myclass['Bill'].value_counts(dropna=False)
# Out:
# NaN     2
# 70.0    1
# Name: Bill, dtype: int64

# %%
myclass['Bill'].isnull().value_counts()
# Out:
# True     2
# False    1
# Name: Bill, dtype: int64

# %%
# default axis is 0 that is rows.
# will drop rows with null values
myclass.dropna()
# Out:
#     Bob  Robin  Bill
# 0  90.0     80  70.0

# %%
# Axis = 1 means columns
# Will drop columns with null values
myclass.dropna(axis=1)
# Out:
#    Robin
# 0     80
# 1     33
# 2     20

# %%
# Giving thresh - requires those many non na values
# than thresh
myclass.dropna(thresh=2)
# Out:
#     Bob  Robin  Bill
# 0  90.0     80  70.0
# 1  95.0     33   NaN

# %%
myclass.dropna(axis=1,thresh=2)
# Out:
#     Bob  Robin
# 0  90.0     80
# 1  95.0     33
# 2   NaN     20

# %%
myclass.dropna(axis=0,thresh=2)
# Out:
#     Bob  Robin  Bill
# 0  90.0     80  70.0
# 1  95.0     33   NaN

# %%
# IF we want we can fillin missing values
myclass.fillna(value='No Marks')
# Out:
#         Bob  Robin      Bill
# 0        90     80        70
# 1        95     33  No Marks
# 2  No Marks     20  No Marks

# %%
# If we want to fillin with mean values
df['Bob'].fillna(value=df['Bob'].mean())

# %%
myclass['Bob'].mean()
# Out:
# 92.5

# %%
# Skip na default is True
myclass['Bob'].mean(skipna=False)
# Out:
# nan

# %%
myclass['Bob'].sum(skipna=False)
# Out:
# nan

# %%
d = {
    'A':[1,2,np.nan],'B': [5,np.nan,np.nan],'C' : [1,2,3]
}

# %%
d

# %%
df = pd.DataFrame(d)

# %%
# droping rows that has null values

# %%
df

# %%
df.dropna()

# %%
# Default axis is 0 means across the rows.

# %%
df.dropna(axis = 1)

# %%
# threshhold - how many non na values to not to be droped

# %%
df.dropna(thresh = 2)

# %%
# filling null values
df.fillna(value = 'noval')

# %%
df

# %%
# filling values with the mean of the columns

# %%
df['A'].fillna(value = df['A'].mean())

# %%
df.drop('newname', axis = 1,inplace = True )

# %%
df

# %% [markdown]
# # Group By
# GroupBy - Function is used to split the data into groups based on some criteria & apply some aggregate funciton . Pandas objects can be split on any of their axes.

# %%
df = pd.read_csv('D:\\Users\\nitin\\datasets\Tele-Cust-Churn.csv',index_col=0)

# %%
df

# %%
df.head()

# %%
'''Groupby - We can group together rows based of a column & 
perform aggregate function'''

# %%
data = {
    'Company':['SamPhone','SamPhone','MIPhone','MIPhone','iPhone','iPhone'],
    'Person':['Jack','Tim','Jenifer','Amy','Sarah','Bob'],
    'Sales':[2000, 3000,2500,1004,9000,2500],
    'Qty':[10,16,12,30,10,12]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Company   Person  Sales  Qty
# 0  SamPhone     Jack   2000   10
# 1  SamPhone      Tim   3000   16
# 2   MIPhone  Jenifer   2500   12
# 3   MIPhone      Amy   1004   30
# 4    iPhone    Sarah   9000   10
# 5    iPhone      Bob   2500   12

# %%
# I want to groupby on Company  - I want to do some aggregate fucntion on sales columns
df.groupby('Company')
# This will give us a groupby object in memory

# %%
grppby = df.groupby('Company')

# %%
# Now I can do aggregate function on this
grppby.mean()
# it will give me mean of sales column only as other column is a string
# Out:
#           Sales  Qty
# Company
# MIPhone    1752   21
# SamPhone   2500   13
# iPhone     5750   11

# %%
# sum 
grppby.sum()
# Out:
#           Sales  Qty
# Company
# MIPhone    3504   42
# SamPhone   5000   26
# iPhone    11500   22

# %%
grppby.std()
# Out:
#                 Sales        Qty
# Company
# MIPhone   1057.831745  12.727922
# SamPhone   707.106781   4.242641
# iPhone    4596.194078   1.414214

# %%
# Selecting any row
grppby.sum().loc['MIPhone']
# Out:
# Sales    3504
# Qty        42
# Name: MIPhone, dtype: int64

# %%
# Doing all the operations in one line
df.groupby('Company').sum()
# Out:
#           Sales  Qty
# Company
# MIPhone    3504   42
# SamPhone   5000   26
# iPhone    11500   22

# %%
df.groupby('Company').sum().loc['MIPhone']
# Out:
# Sales    3504
# Qty        42
# Name: MIPhone, dtype: int64

# %%
grppby.get_group('Bob')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-7ea559b3f1c6> in <module>
# ----> 1 grppby.get_group('Bob')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     678         inds = self._get_index(name)
#     679         if not len(inds):
# --> 680             raise KeyError(name)
#     681
#     682         return obj.take(inds, axis=self.axis)
#
# KeyError: 'Bob'

# %%
df.groupby('Company').describe()
# Out:
#          Sales                                                               \
#          count    mean          std     min     25%     50%     75%     max
# Company
# MIPhone    2.0  1752.0  1057.831745  1004.0  1378.0  1752.0  2126.0  2500.0
# SamPhone   2.0  2500.0   707.106781  2000.0  2250.0  2500.0  2750.0  3000.0
# iPhone     2.0  5750.0  4596.194078  2500.0  4125.0  5750.0  7375.0  9000.0
#
#            Qty
#          count  mean        std   min   25%   50%   75%   max
# Company
# MIPhone    2.0  21.0  12.727922  12.0  16.5  21.0  25.5  30.0
# SamPhone   2.0  13.0   4.242641  10.0  11.5  13.0  14.5  16.0
# iPhone     2.0  11.0   1.414214  10.0  10.5  11.0  11.5  12.0

# %%
df.groupby('Company').describe().transpose()
# Out:
# Company          MIPhone     SamPhone       iPhone
# Sales count     2.000000     2.000000     2.000000
#       mean   1752.000000  2500.000000  5750.000000
#       std    1057.831745   707.106781  4596.194078
#       min    1004.000000  2000.000000  2500.000000
#       25%    1378.000000  2250.000000  4125.000000
#       50%    1752.000000  2500.000000  5750.000000
#       75%    2126.000000  2750.000000  7375.000000
#       max    2500.000000  3000.000000  9000.000000
# Qty   count     2.000000     2.000000     2.000000
#       mean     21.000000    13.000000    11.000000
#       std      12.727922     4.242641     1.414214
#       min      12.000000    10.000000    10.000000
#       25%      16.500000    11.500000    10.500000
#       50%      21.000000    13.000000    11.000000
#       75%      25.500000    14.500000    11.500000
#       max      30.000000    16.000000    12.000000

# %%
df = pd.read_csv('D:\\Users\\nitin\\datasets\Tele-Cust-Churn.csv',index_col=0)

# %%
df.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
#
#                   Contract PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
#
#             MonthlyCharges TotalCharges Churn
# customerID
# 7590-VHVEG           29.85        29.85    No
# 5575-GNVDE           56.95       1889.5    No
# 3668-QPYBK           53.85       108.15   Yes
# 7795-CFOCW           42.30      1840.75    No
# 9237-HQITU           70.70       151.65   Yes

# %%
df.tail()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 6840-RESVB               Yes             DSL            Yes           No
# 2234-XADUH               Yes     Fiber optic             No          Yes
# 4801-JZAZL  No phone service             DSL            Yes           No
# 8361-LTMKD               Yes     Fiber optic             No           No
# 3186-AJIEK                No     Fiber optic            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 6840-RESVB              Yes         Yes         Yes             Yes
# 2234-XADUH              Yes          No         Yes             Yes
# 4801-JZAZL               No          No          No              No
# 8361-LTMKD               No          No          No              No
# 3186-AJIEK              Yes         Yes         Yes             Yes
#
#                   Contract PaperlessBilling              PaymentMethod  \
# customerID
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges TotalCharges Churn
# customerID
# 6840-RESVB           84.80       1990.5    No
# 2234-XADUH          103.20       7362.9    No
# 4801-JZAZL           29.60       346.45    No
# 8361-LTMKD           74.40        306.6   Yes
# 3186-AJIEK          105.65       6844.5    No

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 20)

# %%
#Let me select few columns

# %%
df =  df[['gender', 'SeniorCitizen','tenure','InternetService','StreamingMovies','PaymentMethod','Contract','MonthlyCharges','Churn']]

# %%
df.head()
# Out:
#             gender  SeniorCitizen  tenure InternetService StreamingMovies  \
# customerID
# 7590-VHVEG  Female              0       1             DSL              No
# 5575-GNVDE    Male              0      34             DSL              No
# 3668-QPYBK    Male              0       2             DSL              No
# 7795-CFOCW    Male              0      45             DSL              No
# 9237-HQITU  Female              0       2     Fiber optic              No
#
#                         PaymentMethod        Contract  MonthlyCharges  Churn
# customerID
# 7590-VHVEG           Electronic check  Month-to-month           29.85      0
# 5575-GNVDE               Mailed check        One year           56.95      0
# 3668-QPYBK               Mailed check  Month-to-month           53.85      1
# 7795-CFOCW  Bank transfer (automatic)        One year           42.30      0
# 9237-HQITU           Electronic check  Month-to-month           70.70      1

# %%
#np.where(sample.housing.values == 'yes', 1, 0
df.Churn = np.where(df.Churn.values =='Yes',1,0)

# %%
df.head()
# Out:
#             gender  SeniorCitizen  tenure InternetService StreamingMovies  \
# customerID
# 7590-VHVEG  Female              0       1             DSL              No
# 5575-GNVDE    Male              0      34             DSL              No
# 3668-QPYBK    Male              0       2             DSL              No
# 7795-CFOCW    Male              0      45             DSL              No
# 9237-HQITU  Female              0       2     Fiber optic              No
#
#                         PaymentMethod        Contract  MonthlyCharges  Churn
# customerID
# 7590-VHVEG           Electronic check  Month-to-month           29.85      0
# 5575-GNVDE               Mailed check        One year           56.95      0
# 3668-QPYBK               Mailed check  Month-to-month           53.85      1
# 7795-CFOCW  Bank transfer (automatic)        One year           42.30      0
# 9237-HQITU           Electronic check  Month-to-month           70.70      1

# %%
# Finding out how much gender plays a role in churn
df.groupby('gender').mean()
# Out:
#         SeniorCitizen     tenure  MonthlyCharges     Churn
# gender
# Female       0.162844  32.244553       65.204243  0.269209
# Male         0.161463  32.495359       64.327482  0.261603

# %%
df[['gender','Churn']].groupby('gender').mean()
# Out:
#            Churn
# gender
# Female  0.269209
# Male    0.261603

# %%
df.groupby(['gender','Churn']).mean()
# Out:
#               SeniorCitizen     tenure  MonthlyCharges
# gender Churn
# Female 0           0.128678  37.858768       61.664908
#        1           0.255591  17.004260       74.812087
# Male   0           0.128762  37.289524       60.876914
#        1           0.253763  18.963441       74.066989

# %%
# Looking at the churn by internet service
df[['InternetService','Churn']].groupby('InternetService').mean()
# Out:
#                     Churn
# InternetService
# DSL              0.189591
# Fiber optic      0.418928
# No               0.074050

# %%
# Lets sort the values
df[['InternetService','Churn']].groupby('InternetService').mean().sort_values('Churn')
# Out:
#                     Churn
# InternetService
# No               0.074050
# DSL              0.189591
# Fiber optic      0.418928

# %%
df[['InternetService','Churn']].groupby('InternetService').mean().sort_values('Churn', ascending = False)
# Out:
#                     Churn
# InternetService
# Fiber optic      0.418928
# DSL              0.189591
# No               0.074050

# %%
# We can groupby based on multiple columns
df[['Contract','SeniorCitizen','Churn']].groupby(['Contract','SeniorCitizen']).mean()
# Out:
#                                  Churn
# Contract       SeniorCitizen
# Month-to-month 0              0.395698
#                1              0.546468
# One year       0              0.106781
#                1              0.152632
# Two year       0              0.027097
#                1              0.041379

# %%
df[['gender','Contract','SeniorCitizen','Churn']].groupby(['gender','Contract','SeniorCitizen']).mean()
# Out:
#                                         Churn
# gender Contract       SeniorCitizen
# Female Month-to-month 0              0.406946
#                       1              0.553885
#        One year       0              0.095624
#                       1              0.158416
#        Two year       0              0.024453
#                       1              0.044118
# Male   Month-to-month 0              0.384565
#                       1              0.539216
#        One year       0              0.117117
#                       1              0.146067
#        Two year       0              0.029754
#                       1              0.038961

# %%
df.groupby('gender')['Churn'].mean()
# Out:
# gender
# Female    0.269209
# Male      0.261603
# Name: Churn, dtype: float64

# %%
df.groupby('gender')['Churn'].count()
# Out:
# gender
# Female    3488
# Male      3555
# Name: Churn, dtype: int64

# %%
df.groupby('gender').count()
# Out:
#         SeniorCitizen  tenure  InternetService  StreamingMovies  \
# gender
# Female           3488    3488             3488             3488
# Male             3555    3555             3555             3555
#
#         PaymentMethod  Contract  MonthlyCharges  Churn
# gender
# Female           3488      3488            3488   3488
# Male             3555      3555            3555   3555

# %%
df.groupby('gender').first()
# Out:
#         SeniorCitizen  tenure InternetService StreamingMovies  \
# gender
# Female              0       1             DSL              No
# Male                0      34             DSL              No
#
#            PaymentMethod        Contract  MonthlyCharges  Churn
# gender
# Female  Electronic check  Month-to-month           29.85      0
# Male        Mailed check        One year           56.95      0

# %%
df.groupby('gender').get_group('Male')
# Out:
#            gender  SeniorCitizen  tenure InternetService StreamingMovies  \
# customerID
# 5575-GNVDE   Male              0      34             DSL              No
# 3668-QPYBK   Male              0       2             DSL              No
# 7795-CFOCW   Male              0      45             DSL              No
# 1452-KIOVK   Male              0      22     Fiber optic              No
# 6388-TABGU   Male              0      62             DSL              No
# ...           ...            ...     ...             ...             ...
# 9767-FFLEM   Male              0      38     Fiber optic              No
# 8456-QDAVC   Male              0      19     Fiber optic              No
# 6840-RESVB   Male              0      24             DSL             Yes
# 8361-LTMKD   Male              1       4     Fiber optic              No
# 3186-AJIEK   Male              0      66     Fiber optic             Yes
#
#                         PaymentMethod        Contract  MonthlyCharges  Churn
# customerID
# 5575-GNVDE               Mailed check        One year           56.95      0
# 3668-QPYBK               Mailed check  Month-to-month           53.85      1
# 7795-CFOCW  Bank transfer (automatic)        One year           42.30      0
# 1452-KIOVK    Credit card (automatic)  Month-to-month           89.10      0
# 6388-TABGU  Bank transfer (automatic)        One year           56.15      0
# ...                               ...             ...             ...    ...
# 9767-FFLEM    Credit card (automatic)  Month-to-month           69.50      0
# 8456-QDAVC  Bank transfer (automatic)  Month-to-month           78.70      0
# 6840-RESVB               Mailed check        One year           84.80      0
# 8361-LTMKD               Mailed check  Month-to-month           74.40      1
# 3186-AJIEK  Bank transfer (automatic)        Two year          105.65      0
#
# [3555 rows x 9 columns]

# %%
df.head()
# Out:
#             gender  SeniorCitizen  tenure InternetService StreamingMovies  \
# customerID
# 7590-VHVEG  Female              0       1             DSL              No
# 5575-GNVDE    Male              0      34             DSL              No
# 3668-QPYBK    Male              0       2             DSL              No
# 7795-CFOCW    Male              0      45             DSL              No
# 9237-HQITU  Female              0       2     Fiber optic              No
#
#                         PaymentMethod        Contract  MonthlyCharges  Churn
# customerID
# 7590-VHVEG           Electronic check  Month-to-month           29.85      0
# 5575-GNVDE               Mailed check        One year           56.95      0
# 3668-QPYBK               Mailed check  Month-to-month           53.85      1
# 7795-CFOCW  Bank transfer (automatic)        One year           42.30      0
# 9237-HQITU           Electronic check  Month-to-month           70.70      1

# %%
#  If the class distribution is not balanced, only checking the mean may cause false assumptions. 
# You can apply multiple aggregate functions on the result of groupby. They are not limited to 
# the only count and mean, you can pass the name of the functions as an argument to agg() function.
# Means for each group

# %%
df[['InternetService','tenure']].groupby('InternetService').mean()
# Out:
#                     tenure
# InternetService
# DSL              32.821561
# Fiber optic      32.917959
# No               30.547182

# %%
# Want both mean & count 
df[['InternetService','tenure']].groupby('InternetService').agg(['count','mean'])
# Out:
#                 tenure
#                  count       mean
# InternetService
# DSL               2421  32.821561
# Fiber optic       3096  32.917959
# No                1526  30.547182

# %%
# as_index - True  - keys in groupby become index
df[['InternetService','tenure']].groupby('InternetService', as_index = False).agg(['count','mean'])
# Out:
#                 tenure
#                  count       mean
# InternetService
# DSL               2421  32.821561
# Fiber optic       3096  32.917959
# No                1526  30.547182

# %%
df[['gender','SeniorCitizen','tenure']].groupby(['gender','SeniorCitizen'], as_index = False).agg(['count','mean'])
# Out:
#                      tenure
#                       count       mean
# gender SeniorCitizen
# Female 0               2920  32.171233
#        1                568  32.621479
# Male   0               2981  32.212680
#        1                574  33.963415

# %%
df[['gender','SeniorCitizen','tenure']].groupby(['gender','SeniorCitizen'], as_index = False).mean()
# Out:
#    gender  SeniorCitizen     tenure
# 0  Female              0  32.171233
# 1  Female              1  32.621479
# 2    Male              0  32.212680
# 3    Male              1  33.963415

# %%
df[['gender','SeniorCitizen','tenure']].groupby(['gender','SeniorCitizen']).mean()
# Out:
#                          tenure
# gender SeniorCitizen
# Female 0              32.171233
#        1              32.621479
# Male   0              32.212680
#        1              33.963415

# %%
# Finding out the monthly charges for each contract type
df[['Contract','MonthlyCharges']].groupby('Contract').mean()
# long term contract have less monthly charges
# Out:
#                 MonthlyCharges
# Contract
# Month-to-month       66.398490
# One year             65.048608
# Two year             60.770413

# %%
# Finding out the monthly charges for each contract type
df[['Contract','MonthlyCharges','gender']].groupby(['Contract','gender']).mean()
# Out:
#                        MonthlyCharges
# Contract       gender
# Month-to-month Female       66.652623
#                Male         66.147615
# One year       Female       66.841643
#                Male         63.343444
# Two year       Female       60.513373
#                Male         61.025941

# %%
# Looking at the distribution of contract type for different internet services
df.groupby(['InternetService','Contract']).count()
# Out:
#                                 gender  SeniorCitizen  tenure  \
# InternetService Contract
# DSL             Month-to-month    1223           1223    1223
#                 One year           570            570     570
#                 Two year           628            628     628
# Fiber optic     Month-to-month    2128           2128    2128
#                 One year           539            539     539
#                 Two year           429            429     429
# No              Month-to-month     524            524     524
#                 One year           364            364     364
#                 Two year           638            638     638
#
#                                 StreamingMovies  PaymentMethod  \
# InternetService Contract
# DSL             Month-to-month             1223           1223
#                 One year                    570            570
#                 Two year                    628            628
# Fiber optic     Month-to-month             2128           2128
#                 One year                    539            539
#                 Two year                    429            429
# No              Month-to-month              524            524
#                 One year                    364            364
#                 Two year                    638            638
#
#                                 MonthlyCharges  Churn
# InternetService Contract
# DSL             Month-to-month            1223   1223
#                 One year                   570    570
#                 Two year                   628    628
# Fiber optic     Month-to-month            2128   2128
#                 One year                   539    539
#                 Two year                   429    429
# No              Month-to-month             524    524
#                 One year                   364    364
#                 Two year                   638    638

# %% [markdown]
# # Merging, Joining & Concatenating

# %%
cars = pd.read_csv('D:\\Users\\nitin\\datasets\cars-grp.csv')

# %%
cars['carmodel']
# Out:
# 0              Ford Mondeo LX
# 1              Ford Galaxy LX
# 2           Ford Fiesta 1.25i
# 3         Ford Ka 1.3 HCS EFi
# 4              Opel Astra 1.6
# 5             Opel Vectra 2.0
# 6              Opel Omega MV6
# 7     Volkswagen Golf GLS 2.0
# 8       Volkswagen Passat GLX
# 9      Volkswagen Beetle 2.0L
# 10          Daewoo Leganza SX
# 11           Daewoo Cielo GLE
# 12          Daewoo Nubira CDS
# 13            Daewoo Matiz SE
# 14     Mercedes M-Class ML320
# 15             Volvo V70 2.3L
# 16          BMW 3-series 330i
# 17           Renault Clio RXE
# 18             Renault Megane
# 19         Renault Scenic Rx4
# 20              Fiat Punto 75
# 21           Fiat Bravo SX-GT
# 22      Fiat Multipla 1.6 ELX
# 23             Dacia Nova GTi
# 24    Dacia SupeRNova Confort
# 25      Mercedes C-Class C320
# 26    Mercedes CL-Class CL500
# 27      Mercedes E-Class E320
# 28      Mercedes S-Class S500
# 29             Volvo C70 2.3L
# 30          BMW 5-series 540i
# 31          BMW 7-series 740i
# Name: carmodel, dtype: object

# %%
mystr = 'Nitin monga'

# %%
# mystr.find(' ')
# Out:
# 5

# %%
# mystr[:mystr.find(' ')]
# Out:
# 'Nitin'

# %%
mystr.split(' ')[0]
# Out:
# 'Nitin'

# %%
cars['comp'] = cars['carmodel'].str.split(' ').str[0]

# %%
mycols = cars.columns

# %%
print(mycols)
# Out:
# Index(['carmodel', 'symbol', 'price', 'engine', 'power', 'fuelcons', 'speed',
#        'comp'],
#       dtype='object')

# %%
mycols = ['comp','carmodel', 'symbol', 'price', 'engine', 'power', 'fuelcons', 'speed']

# %%
cars = cars[mycols]

# %%
cars
# Out:
#           comp                 carmodel symbol    price  engine  power  \
# 0         Ford           Ford Mondeo LX    FDM  22170.0    1989  144.0
# 1         Ford           Ford Galaxy LX    FDG  27516.0    2792  201.0
# 2         Ford        Ford Fiesta 1.25i    FDF      NaN    1242   74.0
# 3         Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0
# 4         Opel           Opel Astra 1.6    OPA  18105.0    1598   63.0
# 5         Opel          Opel Vectra 2.0    OPV  19946.0    1998  136.0
# 6         Opel           Opel Omega MV6    OPG      NaN    2962  211.0
# 7   Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0
# 8   Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0
# 9   Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN
# 10      Daewoo        Daewoo Leganza SX    DWL      NaN    1998  133.0
# 11      Daewoo         Daewoo Cielo GLE    DWI   6860.0    1498   80.0
# 12      Daewoo        Daewoo Nubira CDS    DWN   9222.0    1598   78.0
# 13      Daewoo          Daewoo Matiz SE    DWM   4792.0     796   51.0
# 14    Mercedes   Mercedes M-Class ML320    MBM  33950.0    3199  233.0
# 15       Volvo           Volvo V70 2.3L    VLV  43422.0    2319  247.0
# 16         BMW        BMW 3-series 330i    BM3      NaN    2979  225.0
# 17     Renault         Renault Clio RXE    RCT  12542.0    1390   98.0
# 18     Renault           Renault Megane    RTM  17370.0    2965  250.0
# 19     Renault       Renault Scenic Rx4    RTS  22000.0    1998  140.0
# 20        Fiat            Fiat Punto 75    FTP  14370.0    1242   73.0
# 21        Fiat         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN
# 22        Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0
# 23       Dacia           Dacia Nova GTi    DAN   5000.0    1557   72.0
# 24       Dacia  Dacia SupeRNova Confort    DAS      NaN    1390   74.0
# 25    Mercedes    Mercedes C-Class C320    MBC      NaN    3199  215.0
# 26    Mercedes  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0
# 27    Mercedes    Mercedes E-Class E320    MBE      NaN    3199  221.0
# 28    Mercedes    Mercedes S-Class S500    MBS  85250.0    4966    NaN
# 29       Volvo           Volvo C70 2.3L    VLC  50700.0    2319  247.0
# 30         BMW        BMW 5-series 540i    BM5  58985.0    4398  282.0
# 31         BMW        BMW 7-series 740i    BM7  62900.0    5379  326.0
#
#     fuelcons  speed
# 0       11.3    NaN
# 1       14.8  219.0
# 2        8.7  167.0
# 3        8.3  155.0
# 4       11.5  178.0
# 5       13.9  212.0
# 6       16.8  238.0
# 7       11.9  195.0
# 8       13.7  227.0
# 9        9.8  177.0
# 10      10.2  206.0
# 11      10.5  170.0
# 12      11.3  185.0
# 13       7.4  144.0
# 14      18.2  182.0
# 15      11.2    NaN
# 16      11.8  206.0
# 17       8.8  186.0
# 18       9.2    NaN
# 19       7.4  196.0
# 20       7.8  170.0
# 21      10.6  184.0
# 22       9.4  170.0
# 23       9.6  161.0
# 24       NaN  162.0
# 25      12.4    NaN
# 26      15.7  249.0
# 27      11.1    NaN
# 28      19.4  204.0
# 29      11.2  249.0
# 30       NaN  249.0
# 31      18.1  206.0

# %%
cars.isnull()
# Out:
#      comp  carmodel  symbol  price  engine  power  fuelcons  speed
# 0   False     False   False  False   False  False     False   True
# 1   False     False   False  False   False  False     False  False
# 2   False     False   False   True   False  False     False  False
# 3   False     False   False  False   False  False     False  False
# 4   False     False   False  False   False  False     False  False
# 5   False     False   False  False   False  False     False  False
# 6   False     False   False   True   False  False     False  False
# 7   False     False   False  False   False  False     False  False
# 8   False     False   False  False   False  False     False  False
# 9   False     False   False  False   False   True     False  False
# 10  False     False   False   True   False  False     False  False
# 11  False     False   False  False   False  False     False  False
# 12  False     False   False  False   False  False     False  False
# 13  False     False   False  False   False  False     False  False
# 14  False     False   False  False   False  False     False  False
# 15  False     False   False  False   False  False     False   True
# 16  False     False   False   True   False  False     False  False
# 17  False     False   False  False   False  False     False  False
# 18  False     False   False  False   False  False     False   True
# 19  False     False   False  False   False  False     False  False
# 20  False     False   False  False   False  False     False  False
# 21  False     False   False  False   False   True     False  False
# 22  False     False   False  False   False  False     False  False
# 23  False     False   False  False   False  False     False  False
# 24  False     False   False   True   False  False      True  False
# 25  False     False   False   True   False  False     False   True
# 26  False     False   False  False   False  False     False  False
# 27  False     False   False   True   False  False     False   True
# 28  False     False   False  False   False   True     False  False
# 29  False     False   False  False   False  False     False  False
# 30  False     False   False  False   False  False      True  False
# 31  False     False   False  False   False  False     False  False

# %%
cars.isnull().sum()
# Out:
# comp        0
# carmodel    0
# symbol      0
# price       7
# engine      0
# power       3
# fuelcons    2
# speed       5
# dtype: int64

# %%
cars.isnull().sum(axis =1)
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     0
# 5     0
# 6     1
# 7     0
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# 13    0
# 14    0
# 15    1
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    1
# 22    0
# 23    0
# 24    2
# 25    2
# 26    0
# 27    2
# 28    1
# 29    0
# 30    1
# 31    0
# dtype: int64

# %%
cars.set_index('carmodel').isnull().sum(axis = 1)
# Out:
# carmodel
# Ford Mondeo LX             1
# Ford Galaxy LX             0
# Ford Fiesta 1.25i          1
# Ford Ka 1.3 HCS EFi        0
# Opel Astra 1.6             0
# Opel Vectra 2.0            0
# Opel Omega MV6             1
# Volkswagen Golf GLS 2.0    0
# Volkswagen Passat GLX      0
# Volkswagen Beetle 2.0L     1
# Daewoo Leganza SX          1
# Daewoo Cielo GLE           0
# Daewoo Nubira CDS          0
# Daewoo Matiz SE            0
# Mercedes M-Class ML320     0
# Volvo V70 2.3L             1
# BMW 3-series 330i          1
# Renault Clio RXE           0
# Renault Megane             1
# Renault Scenic Rx4         0
# Fiat Punto 75              0
# Fiat Bravo SX-GT           1
# Fiat Multipla 1.6 ELX      0
# Dacia Nova GTi             0
# Dacia SupeRNova Confort    2
# Mercedes C-Class C320      2
# Mercedes CL-Class CL500    0
# Mercedes E-Class E320      2
# Mercedes S-Class S500      1
# Volvo C70 2.3L             0
# BMW 5-series 540i          1
# BMW 7-series 740i          0
# dtype: int64

# %%
cars.isnull().sum().sum()
# Out:
# 17

# %%
cars['comp'].unique()
# Out:
# array(['Ford', 'Opel', 'Volkswagen', 'Daewoo', 'Mercedes', 'Volvo', 'BMW',
#        'Renault', 'Fiat', 'Dacia'], dtype=object)

# %%
# selecting cars models - 
# Ford, Opel, Volkswagen
# # Daewoo, Mdercedes, Volvo
# BMW, Renault, Fiat, Dacia

# %%
df = cars.set_index('comp')

# %%
df
# Out:
#                            carmodel symbol    price  engine  power  fuelcons  \
# comp
# Ford                 Ford Mondeo LX    FDM  22170.0    1989  144.0      11.3
# Ford                 Ford Galaxy LX    FDG  27516.0    2792  201.0      14.8
# Ford              Ford Fiesta 1.25i    FDF      NaN    1242   74.0       8.7
# Ford            Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0       8.3
# Opel                 Opel Astra 1.6    OPA  18105.0    1598   63.0      11.5
# Opel                Opel Vectra 2.0    OPV  19946.0    1998  136.0      13.9
# Opel                 Opel Omega MV6    OPG      NaN    2962  211.0      16.8
# Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0      11.9
# Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0      13.7
# Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN       9.8
# Daewoo            Daewoo Leganza SX    DWL      NaN    1998  133.0      10.2
# Daewoo             Daewoo Cielo GLE    DWI   6860.0    1498   80.0      10.5
# Daewoo            Daewoo Nubira CDS    DWN   9222.0    1598   78.0      11.3
# Daewoo              Daewoo Matiz SE    DWM   4792.0     796   51.0       7.4
# Mercedes     Mercedes M-Class ML320    MBM  33950.0    3199  233.0      18.2
# Volvo                Volvo V70 2.3L    VLV  43422.0    2319  247.0      11.2
# BMW               BMW 3-series 330i    BM3      NaN    2979  225.0      11.8
# Renault            Renault Clio RXE    RCT  12542.0    1390   98.0       8.8
# Renault              Renault Megane    RTM  17370.0    2965  250.0       9.2
# Renault          Renault Scenic Rx4    RTS  22000.0    1998  140.0       7.4
# Fiat                  Fiat Punto 75    FTP  14370.0    1242   73.0       7.8
# Fiat               Fiat Bravo SX-GT    FTB  15830.0    1581    NaN      10.6
# Fiat          Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0       9.4
# Dacia                Dacia Nova GTi    DAN   5000.0    1557   72.0       9.6
# Dacia       Dacia SupeRNova Confort    DAS      NaN    1390   74.0       NaN
# Mercedes      Mercedes C-Class C320    MBC      NaN    3199  215.0      12.4
# Mercedes    Mercedes CL-Class CL500    MBL  66440.0    4966  302.0      15.7
# Mercedes      Mercedes E-Class E320    MBE      NaN    3199  221.0      11.1
# Mercedes      Mercedes S-Class S500    MBS  85250.0    4966    NaN      19.4
# Volvo                Volvo C70 2.3L    VLC  50700.0    2319  247.0      11.2
# BMW               BMW 5-series 540i    BM5  58985.0    4398  282.0       NaN
# BMW               BMW 7-series 740i    BM7  62900.0    5379  326.0      18.1
#
#             speed
# comp
# Ford          NaN
# Ford        219.0
# Ford        167.0
# Ford        155.0
# Opel        178.0
# Opel        212.0
# Opel        238.0
# Volkswagen  195.0
# Volkswagen  227.0
# Volkswagen  177.0
# Daewoo      206.0
# Daewoo      170.0
# Daewoo      185.0
# Daewoo      144.0
# Mercedes    182.0
# Volvo         NaN
# BMW         206.0
# Renault     186.0
# Renault       NaN
# Renault     196.0
# Fiat        170.0
# Fiat        184.0
# Fiat        170.0
# Dacia       161.0
# Dacia       162.0
# Mercedes      NaN
# Mercedes    249.0
# Mercedes      NaN
# Mercedes    204.0
# Volvo       249.0
# BMW         249.0
# BMW         206.0

# %%
#df1 = df.loc[['Ford','Opel','Volkswagen']]

# %%
#df1

# %%
#df2 = df.loc[['Daewoo', 'Mercedes', 'Volvo']]

# %%
#df2

# %%
#df3 = df.loc[['BMW', 'Renault', 'Fiat', 'Dacia']]

# %%
#df3

# %%
# df = df.sort_values(by = ['comp'])
df.sort_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           comp                 carmodel symbol    price  engine  power  \
# 0          BMW        BMW 7-series 740i    BM7  62900.0    5379  326.0
# 1          BMW        BMW 3-series 330i    BM3      NaN    2979  225.0
# 2          BMW        BMW 5-series 540i    BM5  58985.0    4398  282.0
# 3        Dacia  Dacia SupeRNova Confort    DAS      NaN    1390   74.0
# 4        Dacia           Dacia Nova GTi    DAN   5000.0    1557   72.0
# 5       Daewoo          Daewoo Matiz SE    DWM   4792.0     796   51.0
# 6       Daewoo        Daewoo Nubira CDS    DWN   9222.0    1598   78.0
# 7       Daewoo        Daewoo Leganza SX    DWL      NaN    1998  133.0
# 8       Daewoo         Daewoo Cielo GLE    DWI   6860.0    1498   80.0
# 9         Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0
# 10        Fiat         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN
# 11        Fiat            Fiat Punto 75    FTP  14370.0    1242   73.0
# 12        Ford           Ford Mondeo LX    FDM  22170.0    1989  144.0
# 13        Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0
# 14        Ford        Ford Fiesta 1.25i    FDF      NaN    1242   74.0
# 15        Ford           Ford Galaxy LX    FDG  27516.0    2792  201.0
# 16    Mercedes   Mercedes M-Class ML320    MBM  33950.0    3199  233.0
# 17    Mercedes    Mercedes S-Class S500    MBS  85250.0    4966    NaN
# 18    Mercedes    Mercedes E-Class E320    MBE      NaN    3199  221.0
# 19    Mercedes    Mercedes C-Class C320    MBC      NaN    3199  215.0
# 20    Mercedes  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0
# 21        Opel           Opel Omega MV6    OPG      NaN    2962  211.0
# 22        Opel          Opel Vectra 2.0    OPV  19946.0    1998  136.0
# 23        Opel           Opel Astra 1.6    OPA  18105.0    1598   63.0
# 24     Renault         Renault Clio RXE    RCT  12542.0    1390   98.0
# 25     Renault           Renault Megane    RTM  17370.0    2965  250.0
# 26     Renault       Renault Scenic Rx4    RTS  22000.0    1998  140.0
# 27  Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0
# 28  Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0
# 29  Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN
# 30       Volvo           Volvo C70 2.3L    VLC  50700.0    2319  247.0
# 31       Volvo           Volvo V70 2.3L    VLV  43422.0    2319  247.0
#
#     fuelcons  speed
# 0       18.1  206.0
# 1       11.8  206.0
# 2        NaN  249.0
# 3        NaN  162.0
# 4        9.6  161.0
# 5        7.4  144.0
# 6       11.3  185.0
# 7       10.2  206.0
# 8       10.5  170.0
# 9        9.4  170.0
# 10      10.6  184.0
# 11       7.8  170.0
# 12      11.3    NaN
# 13       8.3  155.0
# 14       8.7  167.0
# 15      14.8  219.0
# 16      18.2  182.0
# 17      19.4  204.0
# 18      11.1    NaN
# 19      12.4    NaN
# 20      15.7  249.0
# 21      16.8  238.0
# 22      13.9  212.0
# 23      11.5  178.0
# 24       8.8  186.0
# 25       9.2    NaN
# 26       7.4  196.0
# 27      13.7  227.0
# 28      11.9  195.0
# 29       9.8  177.0
# 30      11.2  249.0
# 31      11.2    NaN

# %%
df1  = df.iloc[0:9]

# %%
df1
# Out:
#      comp                 carmodel symbol    price  engine  power  fuelcons  \
# 0     BMW        BMW 7-series 740i    BM7  62900.0    5379  326.0      18.1
# 1     BMW        BMW 3-series 330i    BM3      NaN    2979  225.0      11.8
# 2     BMW        BMW 5-series 540i    BM5  58985.0    4398  282.0       NaN
# 3   Dacia  Dacia SupeRNova Confort    DAS      NaN    1390   74.0       NaN
# 4   Dacia           Dacia Nova GTi    DAN   5000.0    1557   72.0       9.6
# 5  Daewoo          Daewoo Matiz SE    DWM   4792.0     796   51.0       7.4
# 6  Daewoo        Daewoo Nubira CDS    DWN   9222.0    1598   78.0      11.3
# 7  Daewoo        Daewoo Leganza SX    DWL      NaN    1998  133.0      10.2
# 8  Daewoo         Daewoo Cielo GLE    DWI   6860.0    1498   80.0      10.5
#
#    speed
# 0  206.0
# 1  206.0
# 2  249.0
# 3  162.0
# 4  161.0
# 5  144.0
# 6  185.0
# 7  206.0
# 8  170.0

# %%
df2 = df.iloc[9:21]

# %%
df2
# Out:
#         comp                 carmodel symbol    price  engine  power  \
# 9       Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0
# 10      Fiat         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN
# 11      Fiat            Fiat Punto 75    FTP  14370.0    1242   73.0
# 12      Ford           Ford Mondeo LX    FDM  22170.0    1989  144.0
# 13      Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0
# 14      Ford        Ford Fiesta 1.25i    FDF      NaN    1242   74.0
# 15      Ford           Ford Galaxy LX    FDG  27516.0    2792  201.0
# 16  Mercedes   Mercedes M-Class ML320    MBM  33950.0    3199  233.0
# 17  Mercedes    Mercedes S-Class S500    MBS  85250.0    4966    NaN
# 18  Mercedes    Mercedes E-Class E320    MBE      NaN    3199  221.0
# 19  Mercedes    Mercedes C-Class C320    MBC      NaN    3199  215.0
# 20  Mercedes  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0
#
#     fuelcons  speed
# 9        9.4  170.0
# 10      10.6  184.0
# 11       7.8  170.0
# 12      11.3    NaN
# 13       8.3  155.0
# 14       8.7  167.0
# 15      14.8  219.0
# 16      18.2  182.0
# 17      19.4  204.0
# 18      11.1    NaN
# 19      12.4    NaN
# 20      15.7  249.0

# %%
df3 = df.loc[21:]

# %%
df3
# Out:
#           comp                 carmodel symbol    price  engine  power  \
# 21        Opel           Opel Omega MV6    OPG      NaN    2962  211.0
# 22        Opel          Opel Vectra 2.0    OPV  19946.0    1998  136.0
# 23        Opel           Opel Astra 1.6    OPA  18105.0    1598   63.0
# 24     Renault         Renault Clio RXE    RCT  12542.0    1390   98.0
# 25     Renault           Renault Megane    RTM  17370.0    2965  250.0
# 26     Renault       Renault Scenic Rx4    RTS  22000.0    1998  140.0
# 27  Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0
# 28  Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0
# 29  Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN
# 30       Volvo           Volvo C70 2.3L    VLC  50700.0    2319  247.0
# 31       Volvo           Volvo V70 2.3L    VLV  43422.0    2319  247.0
#
#     fuelcons  speed
# 21      16.8  238.0
# 22      13.9  212.0
# 23      11.5  178.0
# 24       8.8  186.0
# 25       9.2    NaN
# 26       7.4  196.0
# 27      13.7  227.0
# 28      11.9  195.0
# 29       9.8  177.0
# 30      11.2  249.0
# 31      11.2    NaN

# %% [markdown]
# # Concatenation
# Simply concats dataframes together - columns has to be same and in same order

# %%
newdf = pd.concat([df1,df2,df3])

# %%
newdf
# Out:
#           comp                 carmodel symbol    price  engine  power  \
# 0          BMW        BMW 7-series 740i    BM7  62900.0    5379  326.0
# 1          BMW        BMW 3-series 330i    BM3      NaN    2979  225.0
# 2          BMW        BMW 5-series 540i    BM5  58985.0    4398  282.0
# 3        Dacia  Dacia SupeRNova Confort    DAS      NaN    1390   74.0
# 4        Dacia           Dacia Nova GTi    DAN   5000.0    1557   72.0
# 5       Daewoo          Daewoo Matiz SE    DWM   4792.0     796   51.0
# 6       Daewoo        Daewoo Nubira CDS    DWN   9222.0    1598   78.0
# 7       Daewoo        Daewoo Leganza SX    DWL      NaN    1998  133.0
# 8       Daewoo         Daewoo Cielo GLE    DWI   6860.0    1498   80.0
# 9         Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0
# 10        Fiat         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN
# 11        Fiat            Fiat Punto 75    FTP  14370.0    1242   73.0
# 12        Ford           Ford Mondeo LX    FDM  22170.0    1989  144.0
# 13        Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0
# 14        Ford        Ford Fiesta 1.25i    FDF      NaN    1242   74.0
# 15        Ford           Ford Galaxy LX    FDG  27516.0    2792  201.0
# 16    Mercedes   Mercedes M-Class ML320    MBM  33950.0    3199  233.0
# 17    Mercedes    Mercedes S-Class S500    MBS  85250.0    4966    NaN
# 18    Mercedes    Mercedes E-Class E320    MBE      NaN    3199  221.0
# 19    Mercedes    Mercedes C-Class C320    MBC      NaN    3199  215.0
# 20    Mercedes  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0
# 21        Opel           Opel Omega MV6    OPG      NaN    2962  211.0
# 22        Opel          Opel Vectra 2.0    OPV  19946.0    1998  136.0
# 23        Opel           Opel Astra 1.6    OPA  18105.0    1598   63.0
# 24     Renault         Renault Clio RXE    RCT  12542.0    1390   98.0
# 25     Renault           Renault Megane    RTM  17370.0    2965  250.0
# 26     Renault       Renault Scenic Rx4    RTS  22000.0    1998  140.0
# 27  Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0
# 28  Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0
# 29  Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN
# 30       Volvo           Volvo C70 2.3L    VLC  50700.0    2319  247.0
# 31       Volvo           Volvo V70 2.3L    VLV  43422.0    2319  247.0
#
#     fuelcons  speed
# 0       18.1  206.0
# 1       11.8  206.0
# 2        NaN  249.0
# 3        NaN  162.0
# 4        9.6  161.0
# 5        7.4  144.0
# 6       11.3  185.0
# 7       10.2  206.0
# 8       10.5  170.0
# 9        9.4  170.0
# 10      10.6  184.0
# 11       7.8  170.0
# 12      11.3    NaN
# 13       8.3  155.0
# 14       8.7  167.0
# 15      14.8  219.0
# 16      18.2  182.0
# 17      19.4  204.0
# 18      11.1    NaN
# 19      12.4    NaN
# 20      15.7  249.0
# 21      16.8  238.0
# 22      13.9  212.0
# 23      11.5  178.0
# 24       8.8  186.0
# 25       9.2    NaN
# 26       7.4  196.0
# 27      13.7  227.0
# 28      11.9  195.0
# 29       9.8  177.0
# 30      11.2  249.0
# 31      11.2    NaN

# %%
dfc1_left = df[['comp','carmodel','symbol','price']]
dfc2_right = df[['carmodel','engine','power','fuelcons','speed']]

# %%
dfc1_left.head()
# Out:
#     comp                 carmodel symbol    price
# 0    BMW        BMW 7-series 740i    BM7  62900.0
# 1    BMW        BMW 3-series 330i    BM3      NaN
# 2    BMW        BMW 5-series 540i    BM5  58985.0
# 3  Dacia  Dacia SupeRNova Confort    DAS      NaN
# 4  Dacia           Dacia Nova GTi    DAN   5000.0

# %%
dfc2_right.head()
# Out:
#                   carmodel  engine  power  fuelcons  speed
# 0        BMW 7-series 740i    5379  326.0      18.1  206.0
# 1        BMW 3-series 330i    2979  225.0      11.8  206.0
# 2        BMW 5-series 540i    4398  282.0       NaN  249.0
# 3  Dacia SupeRNova Confort    1390   74.0       NaN  162.0
# 4           Dacia Nova GTi    1557   72.0       9.6  161.0

# %%
# concatenating columns 
pd.concat([dfc1_left,dfc2_right], axis=1)
# Out:
#           comp                 carmodel symbol    price  \
# 0          BMW        BMW 7-series 740i    BM7  62900.0
# 1          BMW        BMW 3-series 330i    BM3      NaN
# 2          BMW        BMW 5-series 540i    BM5  58985.0
# 3        Dacia  Dacia SupeRNova Confort    DAS      NaN
# 4        Dacia           Dacia Nova GTi    DAN   5000.0
# 5       Daewoo          Daewoo Matiz SE    DWM   4792.0
# 6       Daewoo        Daewoo Nubira CDS    DWN   9222.0
# 7       Daewoo        Daewoo Leganza SX    DWL      NaN
# 8       Daewoo         Daewoo Cielo GLE    DWI   6860.0
# 9         Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0
# 10        Fiat         Fiat Bravo SX-GT    FTB  15830.0
# 11        Fiat            Fiat Punto 75    FTP  14370.0
# 12        Ford           Ford Mondeo LX    FDM  22170.0
# 13        Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0
# 14        Ford        Ford Fiesta 1.25i    FDF      NaN
# 15        Ford           Ford Galaxy LX    FDG  27516.0
# 16    Mercedes   Mercedes M-Class ML320    MBM  33950.0
# 17    Mercedes    Mercedes S-Class S500    MBS  85250.0
# 18    Mercedes    Mercedes E-Class E320    MBE      NaN
# 19    Mercedes    Mercedes C-Class C320    MBC      NaN
# 20    Mercedes  Mercedes CL-Class CL500    MBL  66440.0
# 21        Opel           Opel Omega MV6    OPG      NaN
# 22        Opel          Opel Vectra 2.0    OPV  19946.0
# 23        Opel           Opel Astra 1.6    OPA  18105.0
# 24     Renault         Renault Clio RXE    RCT  12542.0
# 25     Renault           Renault Megane    RTM  17370.0
# 26     Renault       Renault Scenic Rx4    RTS  22000.0
# 27  Volkswagen    Volkswagen Passat GLX    VWP  28750.0
# 28  Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0
# 29  Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0
# 30       Volvo           Volvo C70 2.3L    VLC  50700.0
# 31       Volvo           Volvo V70 2.3L    VLV  43422.0
#
#                    carmodel  engine  power  fuelcons  speed
# 0         BMW 7-series 740i    5379  326.0      18.1  206.0
# 1         BMW 3-series 330i    2979  225.0      11.8  206.0
# 2         BMW 5-series 540i    4398  282.0       NaN  249.0
# 3   Dacia SupeRNova Confort    1390   74.0       NaN  162.0
# 4            Dacia Nova GTi    1557   72.0       9.6  161.0
# 5           Daewoo Matiz SE     796   51.0       7.4  144.0
# 6         Daewoo Nubira CDS    1598   78.0      11.3  185.0
# 7         Daewoo Leganza SX    1998  133.0      10.2  206.0
# 8          Daewoo Cielo GLE    1498   80.0      10.5  170.0
# 9     Fiat Multipla 1.6 ELX    1581  103.0       9.4  170.0
# 10         Fiat Bravo SX-GT    1581    NaN      10.6  184.0
# 11            Fiat Punto 75    1242   73.0       7.8  170.0
# 12           Ford Mondeo LX    1989  144.0      11.3    NaN
# 13      Ford Ka 1.3 HCS EFi    1299   59.0       8.3  155.0
# 14        Ford Fiesta 1.25i    1242   74.0       8.7  167.0
# 15           Ford Galaxy LX    2792  201.0      14.8  219.0
# 16   Mercedes M-Class ML320    3199  233.0      18.2  182.0
# 17    Mercedes S-Class S500    4966    NaN      19.4  204.0
# 18    Mercedes E-Class E320    3199  221.0      11.1    NaN
# 19    Mercedes C-Class C320    3199  215.0      12.4    NaN
# 20  Mercedes CL-Class CL500    4966  302.0      15.7  249.0
# 21           Opel Omega MV6    2962  211.0      16.8  238.0
# 22          Opel Vectra 2.0    1998  136.0      13.9  212.0
# 23           Opel Astra 1.6    1598   63.0      11.5  178.0
# 24         Renault Clio RXE    1390   98.0       8.8  186.0
# 25           Renault Megane    2965  250.0       9.2    NaN
# 26       Renault Scenic Rx4    1998  140.0       7.4  196.0
# 27    Volkswagen Passat GLX    2771  190.0      13.7  227.0
# 28  Volkswagen Golf GLS 2.0    1984  115.0      11.9  195.0
# 29   Volkswagen Beetle 2.0L    1984    NaN       9.8  177.0
# 30           Volvo C70 2.3L    2319  247.0      11.2  249.0
# 31           Volvo V70 2.3L    2319  247.0      11.2    NaN

# %%
pd.concat([dfc1_left,dfc2_right], axis=1).head()
# Out:
#     comp                 carmodel symbol    price                 carmodel  \
# 0    BMW        BMW 7-series 740i    BM7  62900.0        BMW 7-series 740i
# 1    BMW        BMW 3-series 330i    BM3      NaN        BMW 3-series 330i
# 2    BMW        BMW 5-series 540i    BM5  58985.0        BMW 5-series 540i
# 3  Dacia  Dacia SupeRNova Confort    DAS      NaN  Dacia SupeRNova Confort
# 4  Dacia           Dacia Nova GTi    DAN   5000.0           Dacia Nova GTi
#
#    engine  power  fuelcons  speed
# 0    5379  326.0      18.1  206.0
# 1    2979  225.0      11.8  206.0
# 2    4398  282.0       NaN  249.0
# 3    1390   74.0       NaN  162.0
# 4    1557   72.0       9.6  161.0

# %% [markdown]
# # Inner Join
# Inner join is the most common type of join you’ll be working with. It returns a dataframe with only
# those rows that have common characteristics.
#
# <img src="jyimages/inner.png" width = 300 height = 300 align="left">

# %%
dummy_data1 = {
        'id': ['1', '2', '3', '4', '5'],
        'Feature1': ['A', 'C', 'E', 'G', 'I'],
        'Feature2': ['B', 'D', 'F', 'H', 'J']}

# %%
df1 = pd.DataFrame(dummy_data1, columns = ['id', 'Feature1', 'Feature2'])

df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
dummy_data2 = {
        'id': ['1', '2', '6', '7', '8'],
        'Feature1': ['K', 'M', 'O', 'Q', 'S'],
        'Feature2': ['L', 'N', 'P', 'R', 'T']}

# %%
df2 = pd.DataFrame(dummy_data2, columns = ['id', 'Feature1', 'Feature2'])

df2
# Out:
#   id Feature1 Feature2
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
df2
# Out:
#   id Feature1 Feature2
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
dummy_data3 = {
        'id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'Feature3': [12, 13, 14, 15, 16, 17, 15, 12, 13, 23]}

# %%
df3 = pd.DataFrame(dummy_data3, columns = ['id', 'Feature3'])

df3
# Out:
#    id  Feature3
# 0   1        12
# 1   2        13
# 2   3        14
# 3   4        15
# 4   5        16
# 5   7        17
# 6   8        15
# 7   9        12
# 8  10        13
# 9  11        23

# %%
df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
df2
# Out:
#   id Feature1 Feature2
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
df3
# Out:
#    id  Feature3
# 0   1        12
# 1   2        13
# 2   3        14
# 3   4        15
# 4   5        16
# 5   7        17
# 6   8        15
# 7   9        12
# 8  10        13
# 9  11        23

# %%
# Concatenating DataFrames df1 & df2

# %%
# By default axis is 0 that means concatenate dataframes along the rows
pd.concat([df1,df2])
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
# However, the row labels seem to be wrong! If you want the row labels to adjust 
# automatically according to the join, you will have to set the argument ignore_index as True 
# look at the index
pd.concat([df1,df2], ignore_index=True)
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 5  1        K        L
# 6  2        M        N
# 7  6        O        P
# 8  7        Q        R
# 9  8        S        T

# %%
# We can also label the DataFrames, after the concatenation, 
# with a key so that you may know which data came from which DataFrame
myconc = pd.concat([df1,df2],keys=['k1','k2'])

# %%
myconc
# Out:
#      id Feature1 Feature2
# k1 0  1        A        B
#    1  2        C        D
#    2  3        E        F
#    3  4        G        H
#    4  5        I        J
# k2 0  1        K        L
#    1  2        M        N
#    2  6        O        P
#    3  7        Q        R
#    4  8        S        T

# %%
# selecting data using keys
myconc.loc['k1'].iloc[2]
# Out:
# id          3
# Feature1    E
# Feature2    F
# Name: 2, dtype: object

# %%
# selecting data using keys
myconc.loc['k1']['id']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: id, dtype: object

# %%
# concatenating using axis = 1
pd.concat([df1,df2], axis = 1)
# Out:
#   id Feature1 Feature2 id Feature1 Feature2
# 0  1        A        B  1        K        L
# 1  2        C        D  2        M        N
# 2  3        E        F  6        O        P
# 3  4        G        H  7        Q        R
# 4  5        I        J  8        S        T

# %% [markdown]
# # Merging the data frames

# %%
df_row = pd.concat([df1,df2])

# %%
df_row
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
df3
# Out:
#    id  Feature3
# 0   1        12
# 1   2        13
# 2   3        14
# 3   4        15
# 4   5        16
# 5   7        17
# 6   8        15
# 7   9        12
# 8  10        13
# 9  11        23

# %%
# Merging on the common column

# %%
df_merg_col= pd.merge(df_row, df3, on = 'id')

# %%
df_merg_col
# Out:
#   id Feature1 Feature2  Feature3
# 0  1        A        B        12
# 1  1        K        L        12
# 2  2        C        D        13
# 3  2        M        N        13
# 4  3        E        F        14
# 5  4        G        H        15
# 6  5        I        J        16
# 7  7        Q        R        17
# 8  8        S        T        15

# %%
# If the columns have different names on which we are merging then we use left_on & right_on arguments
pd.merge(df_row, df3, left_on='id', right_on='id')
# Out:
#   id Feature1 Feature2  Feature3
# 0  1        A        B        12
# 1  1        K        L        12
# 2  2        C        D        13
# 3  2        M        N        13
# 4  3        E        F        14
# 5  4        G        H        15
# 6  5        I        J        16
# 7  7        Q        R        17
# 8  8        S        T        15

# %%
# We can add or append rows to a DataFrame by passing a Series or dict

# %%
df_merg_col
# Out:
#   id Feature1 Feature2  Feature3
# 0  1        A        B        12
# 1  1        K        L        12
# 2  2        C        D        13
# 3  2        M        N        13
# 4  3        E        F        14
# 5  4        G        H        15
# 6  5        I        J        16
# 7  7        Q        R        17
# 8  8        S        T        15

# %%
add_row = pd.Series(['10', 'X1', 'X2', 'X3'],
                    index=['id','Feature1', 'Feature2', 'Feature3'])

# %%
add_row
# Out:
# id          10
# Feature1    X1
# Feature2    X2
# Feature3    X3
# dtype: object

# %%
df_add_row = df_merg_col.append(add_row, ignore_index=True)

# %%
df_add_row
# Out:
#    id Feature1 Feature2 Feature3
# 0   1        A        B       12
# 1   1        K        L       12
# 2   2        C        D       13
# 3   2        M        N       13
# 4   3        E        F       14
# 5   4        G        H       15
# 6   5        I        J       16
# 7   7        Q        R       17
# 8   8        S        T       15
# 9  10       X1       X2       X3

# %%
# Joining DataFrames

# %%
# Full Outer Join
# joined DataFrame will contain all records from both the DataFrames and fill in NaNs for missing matches on either side

# %% [markdown]
# <img src="jyimages/joins.png" width = 300 height = 300 align="left">

# %%
df_outer = pd.merge(df1, df2, on='id', how='outer')

# %%
df_outer
# can notice that the resulting DataFrame had all the entries from both the tables with NaN
# values for missing matches on either side. However, one more thing to notice is the suffix 
# which got appended to the column names to show which column came from which DataFrame. 
# The default suffixes are x and y, however, you can modify them by specifying the suffixes
# Out:
#   id Feature1_x Feature2_x Feature1_y Feature2_y
# 0  1          A          B          K          L
# 1  2          C          D          M          N
# 2  3          E          F        NaN        NaN
# 3  4          G          H        NaN        NaN
# 4  5          I          J        NaN        NaN
# 5  6        NaN        NaN          O          P
# 6  7        NaN        NaN          Q          R
# 7  8        NaN        NaN          S          T

# %%
df_outer = pd.merge(df1, df2, left_on='id',right_on='id',how='outer',suffixes=('_left','_right'))

# %%
df_outer
# Out:
#   id Feature1_left Feature2_left Feature1_right Feature2_right
# 0  1             A             B              K              L
# 1  2             C             D              M              N
# 2  3             E             F            NaN            NaN
# 3  4             G             H            NaN            NaN
# 4  5             I             J            NaN            NaN
# 5  6           NaN           NaN              O              P
# 6  7           NaN           NaN              Q              R
# 7  8           NaN           NaN              S              T

# %%
# The INNER JOIN produces only the set of records that match in both DataFrame A and DataFrame B.

# %%
df_inner = pd.merge(df1, df2, on='id', how='inner')

# %%
df_inner
# Out:
#   id Feature1_x Feature2_x Feature1_y Feature2_y
# 0  1          A          B          K          L
# 1  2          C          D          M          N

# %%
# Right Join - 
# The RIGHT JOIN produces a complete set of records from DataFrame B (right DataFrame),
# with the matching records (where available) in DataFrame A (left DataFrame).
# If there is no match, the right side will contain null. 
# All elements of right dataframe

# %%
df_right = pd.merge(df1, df2, on='id', how='right')

# %%
df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
df2
# Out:
#   id Feature1 Feature2
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
df_right
# Out:
#   id Feature1_x Feature2_x Feature1_y Feature2_y
# 0  1          A          B          K          L
# 1  2          C          D          M          N
# 2  6        NaN        NaN          O          P
# 3  7        NaN        NaN          Q          R
# 4  8        NaN        NaN          S          T

# %%
# Left Join
# complete set of records from DataFrame A (left DataFrame), with the matching records (where available) 
# in DataFrame B (right DataFrame). If there is no match, the left side will contain null.

# %%
df_left = pd.merge(df1,df2, on ='id', how = 'left')

# %%
df_left
# Out:
#   id Feature1_x Feature2_x Feature1_y Feature2_y
# 0  1          A          B          K          L
# 1  2          C          D          M          N
# 2  3          E          F        NaN        NaN
# 3  4          G          H        NaN        NaN
# 4  5          I          J        NaN        NaN

# %%
# joining on indexes# 
# to perform the join on the indexes or the row labels. To do so, you have to specify right_index
# (for the indexes of the right DataFrame) and left_index (for the indexes of the left DataFrame) as True

# %%
df_index = pd.merge(df1, df2, right_index=True, left_index=True)

# %%
df_index
# Out:
#   id_x Feature1_x Feature2_x id_y Feature1_y Feature2_y
# 0    1          A          B    1          K          L
# 1    2          C          D    2          M          N
# 2    3          E          F    6          O          P
# 3    4          G          H    7          Q          R
# 4    5          I          J    8          S          T

# %%
# Operations on Data Frames

# %%
cars
# Out:
#           comp                 carmodel symbol    price  engine  power  \
# 0         Ford           Ford Mondeo LX    FDM  22170.0    1989  144.0
# 1         Ford           Ford Galaxy LX    FDG  27516.0    2792  201.0
# 2         Ford        Ford Fiesta 1.25i    FDF      NaN    1242   74.0
# 3         Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0
# 4         Opel           Opel Astra 1.6    OPA  18105.0    1598   63.0
# 5         Opel          Opel Vectra 2.0    OPV  19946.0    1998  136.0
# 6         Opel           Opel Omega MV6    OPG      NaN    2962  211.0
# 7   Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0
# 8   Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0
# 9   Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN
# 10      Daewoo        Daewoo Leganza SX    DWL      NaN    1998  133.0
# 11      Daewoo         Daewoo Cielo GLE    DWI   6860.0    1498   80.0
# 12      Daewoo        Daewoo Nubira CDS    DWN   9222.0    1598   78.0
# 13      Daewoo          Daewoo Matiz SE    DWM   4792.0     796   51.0
# 14    Mercedes   Mercedes M-Class ML320    MBM  33950.0    3199  233.0
# 15       Volvo           Volvo V70 2.3L    VLV  43422.0    2319  247.0
# 16         BMW        BMW 3-series 330i    BM3      NaN    2979  225.0
# 17     Renault         Renault Clio RXE    RCT  12542.0    1390   98.0
# 18     Renault           Renault Megane    RTM  17370.0    2965  250.0
# 19     Renault       Renault Scenic Rx4    RTS  22000.0    1998  140.0
# 20        Fiat            Fiat Punto 75    FTP  14370.0    1242   73.0
# 21        Fiat         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN
# 22        Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0
# 23       Dacia           Dacia Nova GTi    DAN   5000.0    1557   72.0
# 24       Dacia  Dacia SupeRNova Confort    DAS      NaN    1390   74.0
# 25    Mercedes    Mercedes C-Class C320    MBC      NaN    3199  215.0
# 26    Mercedes  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0
# 27    Mercedes    Mercedes E-Class E320    MBE      NaN    3199  221.0
# 28    Mercedes    Mercedes S-Class S500    MBS  85250.0    4966    NaN
# 29       Volvo           Volvo C70 2.3L    VLC  50700.0    2319  247.0
# 30         BMW        BMW 5-series 540i    BM5  58985.0    4398  282.0
# 31         BMW        BMW 7-series 740i    BM7  62900.0    5379  326.0
#
#     fuelcons  speed
# 0       11.3    NaN
# 1       14.8  219.0
# 2        8.7  167.0
# 3        8.3  155.0
# 4       11.5  178.0
# 5       13.9  212.0
# 6       16.8  238.0
# 7       11.9  195.0
# 8       13.7  227.0
# 9        9.8  177.0
# 10      10.2  206.0
# 11      10.5  170.0
# 12      11.3  185.0
# 13       7.4  144.0
# 14      18.2  182.0
# 15      11.2    NaN
# 16      11.8  206.0
# 17       8.8  186.0
# 18       9.2    NaN
# 19       7.4  196.0
# 20       7.8  170.0
# 21      10.6  184.0
# 22       9.4  170.0
# 23       9.6  161.0
# 24       NaN  162.0
# 25      12.4    NaN
# 26      15.7  249.0
# 27      11.1    NaN
# 28      19.4  204.0
# 29      11.2  249.0
# 30       NaN  249.0
# 31      18.1  206.0

# %%
# Finding unique values

# %%
cars['comp'].unique()
# Out:
# array(['Ford', 'Opel', 'Volkswagen', 'Daewoo', 'Mercedes', 'Volvo', 'BMW',
#        'Renault', 'Fiat', 'Dacia'], dtype=object)

# %%
# Finding how many unique values
cars['comp'].nunique()
# Out:
# 10

# %%
# Finding how many times value are repeated
cars['comp'].value_counts()
# Out:
# Mercedes      5
# Daewoo        4
# Ford          4
# Opel          3
# Renault       3
# Fiat          3
# BMW           3
# Volkswagen    3
# Volvo         2
# Dacia         2
# Name: comp, dtype: int64

# %%
# Apply Function
mystr = 'Nitin Monga'

# %%
mystr.split(' ')[0]
# Out:
# 'Nitin'

# %%
def mysplit(x):
    myval = x.split(' ')[0]
    return(myval)

# %%
cars['carmodel'].apply(mysplit)
# Out:
# 0           Ford
# 1           Ford
# 2           Ford
# 3           Ford
# 4           Opel
# 5           Opel
# 6           Opel
# 7     Volkswagen
# 8     Volkswagen
# 9     Volkswagen
# 10        Daewoo
# 11        Daewoo
# 12        Daewoo
# 13        Daewoo
# 14      Mercedes
# 15         Volvo
# 16           BMW
# 17       Renault
# 18       Renault
# 19       Renault
# 20          Fiat
# 21          Fiat
# 22          Fiat
# 23         Dacia
# 24         Dacia
# 25      Mercedes
# 26      Mercedes
# 27      Mercedes
# 28      Mercedes
# 29         Volvo
# 30           BMW
# 31           BMW
# Name: carmodel, dtype: object

# %%
cars.drop('new_mod', axis = 1, inplace=True)

# %%
# Finding out hte length 
cars['comp'].apply(len)
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
# 5      4
# 6      4
# 7     10
# 8     10
# 9     10
# 10     6
# 11     6
# 12     6
# 13     6
# 14     8
# 15     5
# 16     3
# 17     7
# 18     7
# 19     7
# 20     4
# 21     4
# 22     4
# 23     5
# 24     5
# 25     8
# 26     8
# 27     8
# 28     8
# 29     5
# 30     3
# 31     3
# Name: comp, dtype: int64

# %%
# Very common using lambda expression

# %%
cars['comp'].apply(lambda x :x.upper())
# Out:
# 0           FORD
# 1           FORD
# 2           FORD
# 3           FORD
# 4           OPEL
# 5           OPEL
# 6           OPEL
# 7     VOLKSWAGEN
# 8     VOLKSWAGEN
# 9     VOLKSWAGEN
# 10        DAEWOO
# 11        DAEWOO
# 12        DAEWOO
# 13        DAEWOO
# 14      MERCEDES
# 15         VOLVO
# 16           BMW
# 17       RENAULT
# 18       RENAULT
# 19       RENAULT
# 20          FIAT
# 21          FIAT
# 22          FIAT
# 23         DACIA
# 24         DACIA
# 25      MERCEDES
# 26      MERCEDES
# 27      MERCEDES
# 28      MERCEDES
# 29         VOLVO
# 30           BMW
# 31           BMW
# Name: comp, dtype: object

# %%
# removing columns
cars.drop('comp', axis = 1)
# Out:
#                    carmodel symbol    price  engine  power  fuelcons  speed
# 0            Ford Mondeo LX    FDM  22170.0    1989  144.0      11.3    NaN
# 1            Ford Galaxy LX    FDG  27516.0    2792  201.0      14.8  219.0
# 2         Ford Fiesta 1.25i    FDF      NaN    1242   74.0       8.7  167.0
# 3       Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0       8.3  155.0
# 4            Opel Astra 1.6    OPA  18105.0    1598   63.0      11.5  178.0
# 5           Opel Vectra 2.0    OPV  19946.0    1998  136.0      13.9  212.0
# 6            Opel Omega MV6    OPG      NaN    2962  211.0      16.8  238.0
# 7   Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0      11.9  195.0
# 8     Volkswagen Passat GLX    VWP  28750.0    2771  190.0      13.7  227.0
# 9    Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN       9.8  177.0
# 10        Daewoo Leganza SX    DWL      NaN    1998  133.0      10.2  206.0
# 11         Daewoo Cielo GLE    DWI   6860.0    1498   80.0      10.5  170.0
# 12        Daewoo Nubira CDS    DWN   9222.0    1598   78.0      11.3  185.0
# 13          Daewoo Matiz SE    DWM   4792.0     796   51.0       7.4  144.0
# 14   Mercedes M-Class ML320    MBM  33950.0    3199  233.0      18.2  182.0
# 15           Volvo V70 2.3L    VLV  43422.0    2319  247.0      11.2    NaN
# 16        BMW 3-series 330i    BM3      NaN    2979  225.0      11.8  206.0
# 17         Renault Clio RXE    RCT  12542.0    1390   98.0       8.8  186.0
# 18           Renault Megane    RTM  17370.0    2965  250.0       9.2    NaN
# 19       Renault Scenic Rx4    RTS  22000.0    1998  140.0       7.4  196.0
# 20            Fiat Punto 75    FTP  14370.0    1242   73.0       7.8  170.0
# 21         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN      10.6  184.0
# 22    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0       9.4  170.0
# 23           Dacia Nova GTi    DAN   5000.0    1557   72.0       9.6  161.0
# 24  Dacia SupeRNova Confort    DAS      NaN    1390   74.0       NaN  162.0
# 25    Mercedes C-Class C320    MBC      NaN    3199  215.0      12.4    NaN
# 26  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0      15.7  249.0
# 27    Mercedes E-Class E320    MBE      NaN    3199  221.0      11.1    NaN
# 28    Mercedes S-Class S500    MBS  85250.0    4966    NaN      19.4  204.0
# 29           Volvo C70 2.3L    VLC  50700.0    2319  247.0      11.2  249.0
# 30        BMW 5-series 540i    BM5  58985.0    4398  282.0       NaN  249.0
# 31        BMW 7-series 740i    BM7  62900.0    5379  326.0      18.1  206.0

# %%
mynewcar = cars.set_index('carmodel')

# %%
# Will give the index
mynewcar.index
# Out:
# Index(['Ford Mondeo LX', 'Ford Galaxy LX', 'Ford Fiesta 1.25i',
#        'Ford Ka 1.3 HCS EFi', 'Opel Astra 1.6', 'Opel Vectra 2.0',
#        'Opel Omega MV6', 'Volkswagen Golf GLS 2.0', 'Volkswagen Passat GLX',
#        'Volkswagen Beetle 2.0L', 'Daewoo Leganza SX', 'Daewoo Cielo GLE',
#        'Daewoo Nubira CDS', 'Daewoo Matiz SE', 'Mercedes M-Class ML320',
#        'Volvo V70 2.3L', 'BMW 3-series 330i', 'Renault Clio RXE',
#        'Renault Megane', 'Renault Scenic Rx4', 'Fiat Punto 75',
#        'Fiat Bravo SX-GT', 'Fiat Multipla 1.6 ELX', 'Dacia Nova GTi',
#        'Dacia SupeRNova Confort', 'Mercedes C-Class C320',
#        'Mercedes CL-Class CL500', 'Mercedes E-Class E320',
#        'Mercedes S-Class S500', 'Volvo C70 2.3L', 'BMW 5-series 540i',
#        'BMW 7-series 740i'],
#       dtype='object', name='carmodel')

# %%
cars.head()
# Out:
#    comp             carmodel symbol    price  engine  power  fuelcons  speed
# 0  Ford       Ford Mondeo LX    FDM  22170.0    1989  144.0      11.3    NaN
# 1  Ford       Ford Galaxy LX    FDG  27516.0    2792  201.0      14.8  219.0
# 2  Ford    Ford Fiesta 1.25i    FDF      NaN    1242   74.0       8.7  167.0
# 3  Ford  Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0       8.3  155.0
# 4  Opel       Opel Astra 1.6    OPA  18105.0    1598   63.0      11.5  178.0

# %%
# sorting on price
cars.sort_values('price')
# Out:
#           comp                 carmodel symbol    price  engine  power  \
# 13      Daewoo          Daewoo Matiz SE    DWM   4792.0     796   51.0
# 23       Dacia           Dacia Nova GTi    DAN   5000.0    1557   72.0
# 11      Daewoo         Daewoo Cielo GLE    DWI   6860.0    1498   80.0
# 12      Daewoo        Daewoo Nubira CDS    DWN   9222.0    1598   78.0
# 17     Renault         Renault Clio RXE    RCT  12542.0    1390   98.0
# 3         Ford      Ford Ka 1.3 HCS EFi    FDK  13085.0    1299   59.0
# 20        Fiat            Fiat Punto 75    FTP  14370.0    1242   73.0
# 21        Fiat         Fiat Bravo SX-GT    FTB  15830.0    1581    NaN
# 7   Volkswagen  Volkswagen Golf GLS 2.0    VWG  16350.0    1984  115.0
# 18     Renault           Renault Megane    RTM  17370.0    2965  250.0
# 4         Opel           Opel Astra 1.6    OPA  18105.0    1598   63.0
# 22        Fiat    Fiat Multipla 1.6 ELX    FTM  18870.0    1581  103.0
# 5         Opel          Opel Vectra 2.0    OPV  19946.0    1998  136.0
# 9   Volkswagen   Volkswagen Beetle 2.0L    VWB  20243.0    1984    NaN
# 19     Renault       Renault Scenic Rx4    RTS  22000.0    1998  140.0
# 0         Ford           Ford Mondeo LX    FDM  22170.0    1989  144.0
# 1         Ford           Ford Galaxy LX    FDG  27516.0    2792  201.0
# 8   Volkswagen    Volkswagen Passat GLX    VWP  28750.0    2771  190.0
# 14    Mercedes   Mercedes M-Class ML320    MBM  33950.0    3199  233.0
# 15       Volvo           Volvo V70 2.3L    VLV  43422.0    2319  247.0
# 29       Volvo           Volvo C70 2.3L    VLC  50700.0    2319  247.0
# 30         BMW        BMW 5-series 540i    BM5  58985.0    4398  282.0
# 31         BMW        BMW 7-series 740i    BM7  62900.0    5379  326.0
# 26    Mercedes  Mercedes CL-Class CL500    MBL  66440.0    4966  302.0
# 28    Mercedes    Mercedes S-Class S500    MBS  85250.0    4966    NaN
# 2         Ford        Ford Fiesta 1.25i    FDF      NaN    1242   74.0
# 6         Opel           Opel Omega MV6    OPG      NaN    2962  211.0
# 10      Daewoo        Daewoo Leganza SX    DWL      NaN    1998  133.0
# 16         BMW        BMW 3-series 330i    BM3      NaN    2979  225.0
# 24       Dacia  Dacia SupeRNova Confort    DAS      NaN    1390   74.0
# 25    Mercedes    Mercedes C-Class C320    MBC      NaN    3199  215.0
# 27    Mercedes    Mercedes E-Class E320    MBE      NaN    3199  221.0
#
#     fuelcons  speed
# 13       7.4  144.0
# 23       9.6  161.0
# 11      10.5  170.0
# 12      11.3  185.0
# 17       8.8  186.0
# 3        8.3  155.0
# 20       7.8  170.0
# 21      10.6  184.0
# 7       11.9  195.0
# 18       9.2    NaN
# 4       11.5  178.0
# 22       9.4  170.0
# 5       13.9  212.0
# 9        9.8  177.0
# 19       7.4  196.0
# 0       11.3    NaN
# 1       14.8  219.0
# 8       13.7  227.0
# 14      18.2  182.0
# 15      11.2    NaN
# 29      11.2  249.0
# 30       NaN  249.0
# 31      18.1  206.0
# 26      15.7  249.0
# 28      19.4  204.0
# 2        8.7  167.0
# 6       16.8  238.0
# 10      10.2  206.0
# 16      11.8  206.0
# 24       NaN  162.0
# 25      12.4    NaN
# 27      11.1    NaN

# %%
cars.isnull().sum().sum()
# Out:
# 17
