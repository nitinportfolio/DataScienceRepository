# %%
import spacy
from spacy import displacy
from spacy.vocab import Vocab
from spacy.tokens import Doc, Span
from spacy.matcher import Matcher

# %%
nlp = spacy.load('en_core_web_lg')

# %%
#help(spacy)

# %%
text = 'Python & Appple are buying India firm for $1 million. A person from U.S. said'

# %%
doc = nlp(text)

# %%
doc
# Out:
# Python & Appple are buying India firm for $1 million. A person from U.S. said

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
#help(doc)

# %% [markdown]
# ## Tokenization

# %%
for token in doc:
    print(token)
# Out:
# Python
# &
# Appple
# are
# buying
# India
# firm
# for
# $
# 1
# million
# .
# A
# person
# from
# U.S.
# said

# %% [markdown]
# ## Parts of Speech tags & dependencies

# %% [markdown]
# - Text: The original word text.
# - Lemma: The base form of the word.
# - POS: The simple UPOS part-of-speech tag.
# - Tag: The detailed part-of-speech tag.
# - Dep: Syntactic dependency, i.e. the relation between tokens.
# - Shape: The word shape – capitalization, punctuation, digits.
# - is alpha: Is the token an alpha character?
# - is stop: Is the token part of a stop list, i.e. the most common words of the language?
#
# - https://spacy.io/api/token#attributes

# %%
#pos -  Coarse-grained part-of-speech 
#Tag - Fine-grained part-of-speech


for token in doc:
    print(token.text,'--' ,token.lemma_, '--' ,token.pos_, '--' ,token.tag_,
         '--' ,token.dep_, '--' ,token.shape_,'--' , token.is_alpha, '--' ,token.is_stop)
# Out:
# Python -- Python -- PROPN -- NNP -- nsubj -- Xxxxx -- True -- False
# & -- & -- CCONJ -- CC -- cc -- & -- False -- False
# Appple -- Appple -- PROPN -- NNP -- conj -- Xxxxx -- True -- False
# are -- be -- AUX -- VBP -- aux -- xxx -- True -- True
# buying -- buy -- VERB -- VBG -- ROOT -- xxxx -- True -- False
# India -- India -- PROPN -- NNP -- compound -- Xxxxx -- True -- False
# firm -- firm -- NOUN -- NN -- dobj -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# $ -- $ -- SYM -- $ -- quantmod -- $ -- False -- False
# 1 -- 1 -- NUM -- CD -- compound -- d -- False -- False
# million -- million -- NUM -- CD -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# person -- person -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# from -- from -- ADP -- IN -- prep -- xxxx -- True -- True
# U.S. -- U.S. -- PROPN -- NNP -- pobj -- X.X. -- False -- False
# said -- say -- VERB -- VBD -- ROOT -- xxxx -- True -- False

# %%
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="141b55dff0c34bcba708e12107e39d28-0" class="displacy" width="2675" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Python &amp;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Appple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">buying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">firm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">person</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">U.S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-1" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-5" stroke-width="2px" d="M595,264.5 C595,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-141b55dff0c34bcba708e12107e39d28-0-6" stroke-width="2px" d="M1295,264.5 C1295,89.5 1620.0,89.5 1620.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-141b55dff0c34bcba708e12107e39d28-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Python & Appple 0 15 ORG
# India 27 32 GPE
# $1 million 42 52 MONEY
# U.S. 68 72 GPE

# %%
mytext = 'you ate my fruit that is Apple. Now the company Apple will sue you'

# %%
mydoc = nlp(mytext)

# %%
for ent in mydoc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 25 30 ORG
# Apple 48 53 ORG

# %%
mytext1 = 'you ate my Apple'

# %%
mydoc1 = nlp(mytext1)

# %%
for ent in mydoc1.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 11 16 ORG

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python &amp; Appple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  firm for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . A person from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  said</div></span>

# %% [markdown]
# ## Word vectors and similarity

# %%
tokens = nlp('dog cat banana afskfsd dollar pound pound currency')

# %%
for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# banana True 6.700014 False
# afskfsd False 0.0 True
# dollar True 6.6968846 False
# pound True 6.7376127 False
# pound True 6.7376127 False
# currency True 7.468573 False

# %%
doc1 = nlp("I like salty fries and hamburgers.")
doc2 = nlp("Fast food tastes very good.")
doc3 = nlp('Going to home')
doc4 = nlp('I like fries and chips')
# Similarity of two documents
print(doc1, '<->',doc2, doc1.similarity(doc2))

print()

# Similarity of tokens & spans
french_fries = doc1[2:4]
burgers = doc2[5]

print(french_fries, '<->',burgers, french_fries.similarity(burgers))

print()

print(doc1, '<->',doc3, doc1.similarity(doc3))

print()

print(doc1, '<->',doc4, doc1.similarity(doc4))
# Out:
# I like salty fries and hamburgers. <-> Fast food tastes very good. 0.7687607590607203
#
# salty fries <-> . 0.15310697257518768
#
# I like salty fries and hamburgers. <-> Going to home 0.553528567648679
#
# I like salty fries and hamburgers. <-> I like fries and chips 0.9223322674447614

# %%
for token in doc:
    print(token.lex)
# Out:
# <spacy.lexeme.Lexeme object at 0x0000023DD3E31AC0>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>
# <spacy.lexeme.Lexeme object at 0x0000023DC901A900>

# %% [markdown]
# ## Vocab, hashes and lexemes

# %%
doc = nlp('I like coffee and apple')
print(doc.vocab.strings['coffee'])
# Out:
# 3197928453018144401

# %%
doc1 = nlp('I like coffee')
print(doc1.vocab.strings['coffee'])
# Out:
# 3197928453018144401

# %%
print(doc1.vocab.strings[3197928453018144401])
# Out:
# coffee

# %% [markdown]
# - Text: The original text of the lexeme.
# - Orth: The hash value of the lexeme.
# - Shape: The abstract word shape of the lexeme.
# - Prefix: By default, the first letter of the word string.
# - Suffix: By default, the last three letters of the word string.
# - is alpha: Does the lexeme consist of alphabetic characters?
# - is digit: Does the lexeme consist of digits?

# %%
doc = nlp('I like one coffee and 4 apple')

for word in doc:
    lexeme = doc.vocab[word.text]
    print(lexeme.text, lexeme.orth,
         lexeme.shape_, lexeme.prefix_,
         lexeme.suffix_, lexeme.is_alpha,
         lexeme.is_digit, lexeme.is_title,
         lexeme.lang_)
# Out:
# I 4690420944186131903 X I I True False True en
# like 18194338103975822726 xxxx l ike True False False en
# one 17454115351911680600 xxx o one True False False en
# coffee 3197928453018144401 xxxx c fee True False False en
# and 2283656566040971221 xxx a and True False False en
# 4 16743743820210141046 d 4 4 False True False en
# apple 8566208034543834098 xxxx a ple True False False en

# %%
doc = nlp('I love coffee')
print(doc.vocab.strings['coffee'])

print(doc.vocab.strings[3197928453018144401])
# Out:
# 3197928453018144401
# coffee

# %%
empty_doc = Doc(Vocab())

# %%
# print(empty_doc.vocab.strings[3197928453018144401])

# will raise an error :(

# %%
empty_doc.vocab.strings.add('coffee')
# Out:
# 3197928453018144401

# %%
empty_doc.vocab.strings.add('coffeele')
# Out:
# 5017469708292969994

# %%
print(empty_doc.vocab.strings[5017469708292969994])
# Out:
# coffeele

# %%
print(empty_doc.vocab.strings[3197928453018144401])
# Out:
# coffee

# %%
new_doc = Doc(doc.vocab)  # Create new doc with first doc's vocab

# %%
print(new_doc.vocab.strings[3197928453018144401])
# Out:
# coffee

# %%
new_doc = Doc(empty_doc.vocab)

# %%
print(new_doc.vocab.strings[5017469708292969994])
# Out:
# coffeele

# %%
print(new_doc.vocab.strings[3197928453018144401])
# Out:
# coffee

# %%
mytext = 'you ate my fruit that is Apple. Now the company Apple will sue you'
doc = nlp(mytext)

# %%
for tokens in doc:
    print(f'{tokens.text:{12}} {tokens.pos_:{12}} {tokens.tag_}' )
# Out:
# you          PRON         PRP
# ate          VERB         VBD
# my           PRON         PRP$
# fruit        NOUN         NN
# that         PRON         WDT
# is           AUX          VBZ
# Apple        PROPN        NNP
# .            PUNCT        .
# Now          ADV          RB
# the          DET          DT
# company      NOUN         NN
# Apple        PROPN        NNP
# will         AUX          MD
# sue          VERB         VB
# you          PRON         PRP

# %% [markdown]
# ## Visualization

# %%
displacy.render(doc, style = 'dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9aa680f4da574dc68792cf66812803cf-0" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">ate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">fruit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Apple.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">sue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-2" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-6" stroke-width="2px" d="M1295,352.0 C1295,2.0 2150.0,2.0 2150.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9aa680f4da574dc68792cf66812803cf-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9aa680f4da574dc68792cf66812803cf-0-7" stroke-width="2px" d="M1470

# %%
displacy.render(doc, style = 'dep', options={'distance':100, 'compact':True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="381ec1f6eb3b4faeb792f26935ef65f5-0" class="displacy" width="1450" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">ate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">fruit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Apple.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">sue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-0" stroke-width="2px" d="M62,202.0 62,185.33333333333334 141.0,185.33333333333334 141.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,204.0 L58,196.0 66,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-1" stroke-width="2px" d="M262,202.0 262,185.33333333333334 341.0,185.33333333333334 341.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,204.0 L258,196.0 266,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-2" stroke-width="2px" d="M162,202.0 162,168.66666666666666 344.0,168.66666666666666 344.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M344.0,204.0 L348.0,196.0 340.0,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-3" stroke-width="2px" d="M462,202.0 462,185.33333333333334 541.0,185.33333333333334 541.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,204.0 L458,196.0 466,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-4" stroke-width="2px" d="M362,202.0 362,168.66666666666666 544.0,168.66666666666666 544.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M544.0,204.0 L548.0,196.0 540.0,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-5" stroke-width="2px" d="M562,202.0 562,185.33333333333334 641.0,185.33333333333334 641.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M641.0,204.0 L645.0,196.0 637.0,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-6" stroke-width="2px" d="M762,202.0 762,135.33333333333331 1250.0,135.33333333333331 1250.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-381ec1f6eb3b4faeb792f26935ef65f5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M762,204.0 L758,196.0 766,196.0"

# %%
for sent in doc.sents:
    print(sent)
# Out:
# you ate my fruit that is Apple.
# Now the company Apple will sue you

# %%
doc
# Out:
# you ate my fruit that is Apple. Now the company Apple will sue you

# %%
mytext = 'you will eat a fruit that is Apple. Now the company Apple will sue you'

# %%
doc = nlp(mytext)

# %%
#pattern = [[{'ENT_TYPE':'ORG','OP':'+'}],[{'LOWER':'sue','validate':True}],
#pattern =        [[{'POS':'NOUN','OP':'+'}],[{'TEXT':'fruit','OP':'+'}]]
pattern = [{'POS':'NOUN','OP':'*'},{'ENT_TYPE':'ORG','OP':'*'},{'POS':'VERB','OP':'*'}]

# %%
matcher = Matcher(nlp.vocab)
matcher.add('1',[pattern])

# %%
matches = matcher(doc)

# %%
matches
# Out:
# [(5533571732986600803, 2, 3),
#  (5533571732986600803, 4, 5),
#  (5533571732986600803, 7, 8),
#  (5533571732986600803, 11, 12),
#  (5533571732986600803, 11, 13),
#  (5533571732986600803, 12, 13),
#  (5533571732986600803, 14, 15)]

# %%
for i in matches:
    print(i)
# Out:
# (5533571732986600803, 2, 3)
# (5533571732986600803, 4, 5)
# (5533571732986600803, 7, 8)
# (5533571732986600803, 11, 12)
# (5533571732986600803, 11, 13)
# (5533571732986600803, 12, 13)
# (5533571732986600803, 14, 15)

# %%
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]
    span= doc[start:end]
    text1 = text[start:end]
    print(match_id, string_id, start, end, span.text,
         span.ents,span.lemma_)
# Out:
# 5533571732986600803 1 2 3 eat [] eat
# 5533571732986600803 1 4 5 fruit [] fruit
# 5533571732986600803 1 7 8 Apple [Apple] Apple
# 5533571732986600803 1 11 12 company [] company
# 5533571732986600803 1 11 13 company Apple [Apple] company Apple
# 5533571732986600803 1 12 13 Apple [Apple] Apple
# 5533571732986600803 1 14 15 sue [] sue

# %%
def on_match(matcher, doc, id, matches):
    print('Matched!', matches)

matcher = Matcher(nlp.vocab)
patterns = [
   [{"LOWER": "hello"}, {"LOWER": "world"}],
   [{"ORTH": "Google"}, {"ORTH": "Maps"}]
]
matcher.add("TEST_PATTERNS", patterns)
doc = nlp("HELLO WORLD on Google Maps.")
matches = matcher(doc)

# %% [markdown]
# ## Regular Expression
#
# # using re package
# - Will do it later

# %% [markdown]
# ## Pipleline Processing

# %%
#mytext = [text, 'Appole is planning ot invest five million dollars in India. Making total investment of $1.8b']

# %%
# mytext = mytext.copy()

# %%
mytext = ['Python & Appple are buying India firm for $1 million. A person from U.S. said',
 'Appole is planning ot invest five million dollars in India. Making total investment of $1.8b']

# %%
nlp = spacy.load('en_core_web_lg')

# %%
# %%timeit

# Lets disable tagger & parserer
docs = nlp.pipe(mytext, disable= ['tagger', 'parser'])
for doc in docs:
    for ent in doc.ents:
        print(ent.text, ent.label_)
    print()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# ...
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# Python & Appple ORG
# India GPE
# $1 million MONEY
# U.S. GPE
#
# Appole PRODUCT
# five million dollars MONEY
# India GPE
# 1.8b MONEY
#
# 18.7 ms ± 925 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
